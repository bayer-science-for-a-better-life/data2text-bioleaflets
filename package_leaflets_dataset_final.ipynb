# %%
import json
import pickle

# %%
# load array of objects, where object - class Leaflet
with open("datasets/LEAFLET_TRAIN_DATASET.pickle", "rb") as f:
    train_dataset = pickle.load(f)

# %%
# load array of objects, where object - class Leaflet
with open("datasets/LEAFLET_VALID_DATASET.pickle", "rb") as f:
    valid_dataset = pickle.load(f)

# %%
# load array of objects, where object - class Leaflet
with open("datasets/LEAFLET_TEST_DATASET.pickle", "rb") as f:
    test_dataset = pickle.load(f)

# %%
def save_dataset_json(dataset, path):
    """
    Save all leaflets in dataset separately as json files
    """
    
    for leaflet in dataset:
        
        # create one dictionary containing all leaflet info
        leaflet_content = {
            'ID': leaflet.id,
            'URL': leaflet.url,
            'Product_Name': leaflet.product_name,
            'Full_Content': leaflet.content,

            'Section_1': {
                'Title': leaflet.section1.title,
                'Section_Content': leaflet.section1.section_content,
                'Entity_Recognition': leaflet.section1.entity_recognition
            },

            'Section_2': {
                'Title': leaflet.section2.title,
                'Section_Content': leaflet.section2.section_content,
                'Entity_Recognition': leaflet.section2.entity_recognition
            },

            'Section_3': {
                'Title': leaflet.section3.title,
                'Section_Content': leaflet.section3.section_content,
                'Entity_Recognition': leaflet.section3.entity_recognition
            },

            'Section_4': {
                'Title': leaflet.section4.title,
                'Section_Content': leaflet.section4.section_content,
                'Entity_Recognition': leaflet.section4.entity_recognition
            },

            'Section_5': {
                'Title': leaflet.section5.title,
                'Section_Content': leaflet.section5.section_content,
                'Entity_Recognition': leaflet.section5.entity_recognition
            },

            'Section_6': {
                'Title': leaflet.section6.title,
                'Section_Content': leaflet.section6.section_content,
                'Entity_Recognition': leaflet.section6.entity_recognition
            }
        }
        
        # location where to save
        FILENAME = path + leaflet_content['ID'] + '.json'
        
        # save leaflet as a json file
        with open(FILENAME, 'w') as fp:
            json.dump(leaflet_content, fp)
        
        # logging
        print('Successfully saved leaflet with ID ~ ', leaflet_content['ID'])
    
    print('\t\t~~~~~~~~~~ Successfully saved all leaflets ~~~~~~~~~~')

# %%
# save all leaflets in training dataset 
save_dataset_json(train_dataset, 'datasets/train/')
# Out:
# Successfully saved leaflet with ID ~  F070D43CC0BF731FAF0E038009F2AD8C
# Successfully saved leaflet with ID ~  498D64FBF7FF865C90BA61D96CEA2777
# Successfully saved leaflet with ID ~  2F819B4E3127C1F56B521862BC986E16
# Successfully saved leaflet with ID ~  EB66C75BD94F0769D967D4889E8B3CAE
# Successfully saved leaflet with ID ~  660E5429A2073BF40C2FE0C2C73B03E2
# Successfully saved leaflet with ID ~  0B6B1FB1EF2BF8BE2D880507FBFFF23E
# Successfully saved leaflet with ID ~  53AAE2FF0EE73654C754B86933606602
# Successfully saved leaflet with ID ~  720F78A7703D3E2E7C3D8BB234DCCDCE
# Successfully saved leaflet with ID ~  F06F840DA278C3A1DA69B80FBABB1621
# Successfully saved leaflet with ID ~  B5329FC7F67D2A3157F38FC5C5AE3936
# Successfully saved leaflet with ID ~  8D9A3FD7E9582B9DF2B8E18B76EA8871
# Successfully saved leaflet with ID ~  A4987B5B94633ECA284462FF6DC00352
# Successfully saved leaflet with ID ~  71335F505B0799776E61738E2D91067C
# ...

# %%
# save all leaflets in validation dataset 
save_dataset_json(valid_dataset, 'datasets/valid/')
# Out:
# Successfully saved leaflet with ID ~  AA65AE65FD33F5909A3E3993EBF62F6B
# Successfully saved leaflet with ID ~  64A2E099C72A8D4B5573EC1AD1F4CD59
# Successfully saved leaflet with ID ~  5C7871981C00E794B4C5DFA4C5DBBB63
# Successfully saved leaflet with ID ~  4597E77AC95D2F440A76C75614847A17
# Successfully saved leaflet with ID ~  EDE61F8A64F525E5A53C77CC05ECC873
# Successfully saved leaflet with ID ~  7C436D14FB533BD570DBB8B952F3DDB7
# Successfully saved leaflet with ID ~  D961792C93DB92F96389F20C50AE801B
# Successfully saved leaflet with ID ~  0162EFDB3D97EC9E4E91C82034D9BCD5
# Successfully saved leaflet with ID ~  49D44FBAE6A156140FEDCF3DB24B144F
# Successfully saved leaflet with ID ~  4DA049427BACB9987C7351997891F48B
# Successfully saved leaflet with ID ~  18C05AD7366B6A4CA7C7B145ED439537
# Successfully saved leaflet with ID ~  2E303DF831A7E8A52BC8FFC5A941EA30
# Successfully saved leaflet with ID ~  5D0AFA9E9ABBB5ED6426B7A28375E9A2
# ...

# %%
# save all leaflets in test dataset 
save_dataset_json(test_dataset, 'datasets/test/')
# Out:
# Successfully saved leaflet with ID ~  97758F197732489D479B37E7D60314C1
# Successfully saved leaflet with ID ~  BABFCC29D7AEBE9CAF42257A48991050
# Successfully saved leaflet with ID ~  EBC079AA886DA3F42DBD3AC431CF0D48
# Successfully saved leaflet with ID ~  32FD8400011F7F50918F570BD6D6653C
# Successfully saved leaflet with ID ~  28828AA4B70553C6AA633C8BDC9AFDC7
# Successfully saved leaflet with ID ~  4BB3D709BCDC3F01E6D5E903BDF642AF
# Successfully saved leaflet with ID ~  28E12D44E03B61517238D38308D78180
# Successfully saved leaflet with ID ~  2F69C58B53BD4BB60C758EB36620BD2B
# Successfully saved leaflet with ID ~  41E281CD11989F344B26E53686B69166
# Successfully saved leaflet with ID ~  722F34103230EAAB66AD286D15D5279E
# Successfully saved leaflet with ID ~  3B98C791CC2CED2DA546A015A5ADA96F
# Successfully saved leaflet with ID ~  36BF9E9AF8E89120C4E14AC151621A52
# Successfully saved leaflet with ID ~  E9DACEAAB5D47AB75F0AEAFDA99E2DF9
# ...

# %% [markdown]
# ### Test

# %% [markdown]
# Check that number of saved files equals number of leaflets in corresponding dataset.

# %%
import os, os.path

# path joining version for other paths
DIR = 'datasets/test/'
assert len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) == len(test_dataset)

DIR = 'datasets/train/'
assert len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) == len(train_dataset)

DIR = 'datasets/valid/'
assert len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) == len(valid_dataset)
