# %% [markdown]
# ## Evaluation Metrics using Entities
#
#
# Our own metrics to capture/measure the hallucination, missing facts effect as well as faithfulness of a model.

# %%
import re
import numpy as np

# for matching entities in generated/original sections
from nltk.tokenize import wordpunct_tokenize

# %% [markdown]
# ### Evaluate BART generations
#
# **Note**: inputs are same as for the T5 model

# %%
# old - from Ruslan
#PATH_FINE_TUNING_ENTITIES = "/home/angelo_ziletti/nlg-ra/T5_experiments/T5_plain/input_data/train.source"
#PATH_TEST_INPUTS = "/home/angelo_ziletti/nlg-ra/T5_experiments/T5_plain/input_data/test.source"
#PATH_TEST_OUTPUTS = "/home/angelo_ziletti/nlg-ra/results/bart/test_generations_beam_1.txt"
#PATH_ORIGINAL_OUTPUTS = "/home/angelo_ziletti/nlg-ra/T5_experiments/T5_plain/input_data/test.target"

# %%
import os.path

# this is fixed 
PATH_FINE_TUNING_ENTITIES = "/home/angelo_ziletti/nlg-ra/T5_experiments/T5_plain/input_data/train.source"

ROOT_FOLDER = "/home/angelo_ziletti/nlg-ra/T5_experiments"

#MODEL = "T5_plain"
#PARTIAL_PATH_GENERATED = "hp_1e_3_1/test_generations_beam_1.txt"
#MODEL = "T5_condition"
MODEL = "T5_condition_semantics"
#MODEL = "BART_base"
#MODEL = "BART_condition"
#MODEL = "BART_condition_semantics"


PARTIAL_PATH_GENERATED = "outputs/test_generations_beam_1.txt"
PARTIAL_PATH_ORIGINAL = "input_data/test.target"
PARTIAL_PATH_TEST_INPUTS = "input_data/test.source"

PATH_GENERATED = os.path.abspath(os.path.normpath(os.path.join(ROOT_FOLDER, MODEL, PARTIAL_PATH_GENERATED)))
PATH_ORIGINAL = os.path.abspath(os.path.normpath(os.path.join(ROOT_FOLDER, MODEL, PARTIAL_PATH_ORIGINAL)))
PATH_TEST_INPUTS = os.path.abspath(os.path.normpath(os.path.join(ROOT_FOLDER, MODEL, PARTIAL_PATH_TEST_INPUTS)))


PATH_TEST_OUTPUTS = PATH_GENERATED
PATH_ORIGINAL_OUTPUTS = PATH_ORIGINAL

print("PATH_TEST_INPUTS: {}".format(PATH_TEST_INPUTS))
print("PATH_TEST_OUTPUTS: {}".format(PATH_TEST_OUTPUTS))
print("PATH_ORIGINAL_OUTPUTS: {}".format(PATH_ORIGINAL_OUTPUTS))
print("PATH_FINE_TUNING_ENTITIES: {}".format(PATH_FINE_TUNING_ENTITIES))
# Out:
# PATH_TEST_INPUTS: /home/angelo_ziletti/nlg-ra/T5_experiments/T5_condition_semantics/input_data/test.source
# PATH_TEST_OUTPUTS: /home/angelo_ziletti/nlg-ra/T5_experiments/T5_condition_semantics/outputs/test_generations_beam_1.txt
# PATH_ORIGINAL_OUTPUTS: /home/angelo_ziletti/nlg-ra/T5_experiments/T5_condition_semantics/input_data/test.target
# PATH_FINE_TUNING_ENTITIES: /home/angelo_ziletti/nlg-ra/T5_experiments/T5_plain/input_data/train.source

# %% [markdown]
# Load data

# %%
with open(PATH_TEST_OUTPUTS) as f:
    test_outputs = [line.strip() for line in f]

# %%
with open(PATH_ORIGINAL_OUTPUTS) as f:
    original_outputs = [line.strip() for line in f]

# %%
with open(PATH_FINE_TUNING_ENTITIES) as f:
    finetuning_entities = [line.strip() for line in f]

# %%
with open(PATH_TEST_INPUTS) as f:
    test_inputs = [line.strip() for line in f]

# %%
# check 
assert len(original_outputs) == len(test_outputs)
assert len(test_inputs) == len(test_outputs)

# %% [markdown]
# ### Get all the entities used in fine-tuning step
#
# (under the assumption that that's where hallucination comes from)
#
# Basically get all the unique entities used during fine-tuning a model aka all the unique entities from train input dataset

# %%
# keys - unique entities from all the section across train dataset
entities_finetuning = dict()

for section_entities in finetuning_entities:
    
    # take into account only entities - uncomment in case there is conditioning on a section
    # section_entities = section_entities.split(":", 1)[1]
    
    # get only the entity_value
    section_entities = re.sub('<[^>]+>', '', section_entities)
    section_entities = section_entities.split()
    
    for entity in section_entities:
        
        # case when entity is long
        words_in_entity = entity.split("_")
        detected_entity = " ".join(words_in_entity)
        
        if detected_entity in entities_finetuning: entities_finetuning[detected_entity] += 1
        else: entities_finetuning[detected_entity] = 1

# %%
# number of unique entities in fine-tuning
len(entities_finetuning)
# Out:
# 54797

# %%
# check out the most popular entities (TOP_ENTITIES) in train input dataset

sorted_entities_finetuning = {k: v for k, v in sorted(entities_finetuning.items(), key=lambda item: item[1], reverse=True)}

TOP_ENTITIES = 20

for entity in sorted_entities_finetuning:
    print(entity, sorted_entities_finetuning[entity])
    TOP_ENTITIES -= 1
    if TOP_ENTITIES == 0: break
# Out:
# side effects 9361
# this medicine 8540
# 1 6815
# pregnant 3635
# 10 3372
# treatment 3212
# medicines 2618
# 2 2434
# 100 2194
# pregnancy 2085
# other medicines 2021
# symptoms 1629
# fever 1557
# 4 1537
# 3 1434
# 6 1424
# vomiting 1321
# dizziness 1282
# skin 1276
# pain 1234

# %% [markdown]
# ### Get unique entities per each sample in test set

# %%
print('Num. of test inputs:', len(test_inputs))
# Out:
# Num. of test inputs: 742

# %%
# list of dicts where each dict is a collection of (entity, num. of times it appears in corresponding *test_inputs*)
entities_inputs = list()

for section_entities in test_inputs:
    
    # take into account only entities (remove section) - uncomment in case there is conditioning on a section
    # section_entities = section_entities.split(":", 1)[1]
    
    # get only the entity_value
    section_entities = re.sub('<[^>]+>', '', section_entities)
    section_entities = section_entities.split()
    
    # keep unique entities for the current section_entities in test_input
    current_section_entities = dict()
    
    for entity in section_entities:
        
        # case when entity is long
        words_in_entity = entity.split("_")
        detected_entity = " ".join(words_in_entity)
        
        if detected_entity in current_section_entities: current_section_entities[detected_entity] += 1
        else: current_section_entities[detected_entity] = 1
    
    # add to the list
    entities_inputs.append(current_section_entities)

# %%
print('[Before] Test input of one section looks like: ')
print(test_inputs[0])
# Out:
# [Before] Test input of one section looks like:
# what the medicine is and what it is used for: <PRODUCT_NAME> incivo </PRODUCT_NAME> <PROBLEM> the_virus </PROBLEM> <DX_NAME> hepatitis_c_infection </DX_NAME> <PROBLEM> chronic_hepatitis_c_infection </PROBLEM> <AGE> 1865 </AGE> <GENERIC_NAME> peginterferon_alfa </GENERIC_NAME> <GENERIC_NAME> ribavirin </GENERIC_NAME> <GENERIC_NAME> telaprevir </GENERIC_NAME> <TREATMENT> medicines </TREATMENT> <TREATMENT_NAME> ns3-4a_protease_inhibitors </TREATMENT_NAME> <TREATMENT> the_ns3-4a_protease_inhibitor </TREATMENT> <DX_NAME> hepatitis_c_virus </DX_NAME> <GENERIC_NAME> peginterferon_alfa </GENERIC_NAME> <GENERIC_NAME> ribavirin </GENERIC_NAME> <TREATMENT> incivo </TREATMENT> <PROBLEM> chronic_hepatitis_c_infection </PROBLEM> <PROBLEM> chronic_hepatitis_c_infection </PROBLEM> <TIME_TO_TREATMENT_NAME> previously </TIME_TO_TREATMENT_NAME> <TREATMENT> an_interferon-based_regimen </TREATMENT>

# %%
print('[After] Test input of one section looks like: ')
print(entities_inputs[0])
# Out:
# [After] Test input of one section looks like:
# {'what': 2, 'the': 1, 'medicine': 1, 'is': 2, 'and': 1, 'it': 1, 'used': 1, 'for:': 1, 'incivo': 2, 'the virus': 1, 'hepatitis c infection': 1, 'chronic hepatitis c infection': 3, '1865': 1, 'peginterferon alfa': 2, 'ribavirin': 2, 'telaprevir': 1, 'medicines': 1, 'ns3-4a protease inhibitors': 1, 'the ns3-4a protease inhibitor': 1, 'hepatitis c virus': 1, 'previously': 1, 'an interferon-based regimen': 1}

# %%
assert len(entities_inputs) == len(test_inputs)

# %% [markdown]
# ## Now the fun part - metrics calculation - Faithfulness, Missing facts, Hallucination

# %%
test_outputs[0]
# Out:
# 'incivo works by stopping the virus from multiplying in the body . inciva is used to treat chronic hepatitis c infection in adults ( including those of 1865 years of age ) in combination with peginterferon alfa - 2b , ribavirin and telaprevir , which are medicines called ns3 - 4a protease inhibitors . the nn3 -4a proteace inhibitor is a natural antibody that helps to protect you from hepatis b virus . pegInterferon atfa and rib virin are the active ingredients of inciVO . what is chronic : incive is used for treating chronic hempatiti c disease in adults . it is used in addition to long - term patients with chronic hc infection who have not previously responded to an'

# %% [markdown]
# **Note**: in the generations, punctuations are treated separately.

# %%
entities_inputs[0]
# Out:
# {'what': 2,
#  'the': 1,
#  'medicine': 1,
#  'is': 2,
#  'and': 1,
#  'it': 1,
#  'used': 1,
#  'for:': 1,
#  'incivo': 2,
#  'the virus': 1,
#  'hepatitis c infection': 1,
#  'chronic hepatitis c infection': 3,
#  '1865': 1,
#  'peginterferon alfa': 2,
#  'ribavirin': 2,
#  'telaprevir': 1,
#  'medicines': 1,
#  'ns3-4a protease inhibitors': 1,
#  'the ns3-4a protease inhibitor': 1,
#  'hepatitis c virus': 1,
#  'previously': 1,
#  'an interferon-based regimen': 1}

# %%
# for each test sample, keep track on entities from entities_inputs included in the test_output
ENTITIES_INCLUDED = []

# for each test sample, keep track on entities from entities_inputs NOT included in the test_output
ENTITIES_NOT_INCLUDED = []

for section_index, section_entities in enumerate(entities_inputs):
    
    # get the corresponding test output for the current section_entities
    curr_output = test_outputs[section_index]
    
    # for each test sample, keep trach of entities included in generated text and not included
    curr_entities_present = []
    curr_entities_not_present = []
    
    for entity in section_entities:
        
        # in case entity has punctuation, tokenize it in order to match the style of test_output
        entity = wordpunct_tokenize(entity)
        entity = " ".join(entity)  
        
        if entity in curr_output:
            
            # important - check that there is a whitespace around entity in curr_output
            start_entity = curr_output.index(entity)
            end_entity = curr_output.index(entity) + len(entity)
            
            ## make sure that entity is not a substring of a word
            
            if not curr_output[start_entity-1].isalpha() and end_entity >= len(curr_output):
                curr_entities_present.append(entity)
            elif not curr_output[start_entity-1].isalpha() and not curr_output[end_entity].isalpha():
                curr_entities_present.append(entity)
            else:
                curr_entities_not_present.append(entity)
        else:
            curr_entities_not_present.append(entity)
    
    ENTITIES_INCLUDED.append(curr_entities_present)
    ENTITIES_NOT_INCLUDED.append(curr_entities_not_present)

# %%
len(ENTITIES_INCLUDED)
# Out:
# 742

# %%
len(ENTITIES_NOT_INCLUDED)
# Out:
# 742

# %% [markdown]
# ### Measuring the Hallucination Effect

# %%
def _is_digit_letter(char):
    """ Helper function to check whether character is digit or a letter"""
    if char.isdigit() or char.isalpha():
        return True
    
    return False

# %%
# save hallucination entities per each test sample
# list of lists

HALLUCINATED_ENTITIES = []

for sample_ind in range(len(test_outputs)):
    
    # get generated text at this index
    generated_section = test_outputs[sample_ind]
    
    # get input entities at this index
    input_entities = entities_inputs[sample_ind]
    
    curr_hallucination_entities = []
    
    # for each unique from train input entities (used in fine-tuning)
    # find out entities present in test_output but not in corresponding entities_inputs
    for entity in entities_finetuning:
        
        # tokenize entity in order to check whether it is present in text generation
        entity_token = wordpunct_tokenize(entity)
        entity_token = " ".join(entity)
        
        # input_entities and entity have same format so do not check whether entity_token in input_entities
        if entity_token in generated_section and entity not in input_entities:
            
            # make sure that it is indeed <entity> in generated_section and not a substring of a token
            # important - check that there is a whitespace around entity in curr_output
            start_entity = generated_section.index(entity_token)
            end_entity = generated_section.index(entity_token) + len(entity_token)
            
            # edge cases when entity - at the begining
            if start_entity == 0 and not _is_digit_letter(generated_section[end_entity]):
                curr_hallucination_entities.append(entity_token)
            # edge cases when entity - at the end
            elif not _is_digit_letter(generated_section[start_entity-1]) and end_entity >= len(generated_section):
                curr_hallucination_entities.append(entity_token)
            elif not _is_digit_letter(generated_section[start_entity-1]) and not _is_digit_letter(generated_section[end_entity]):
                curr_hallucination_entities.append(entity_token)
            
            # else - current entity is part of a token in generated text - do not count such entity
    
    HALLUCINATED_ENTITIES.append(curr_hallucination_entities)

# %%
# save hallucination entities per each test sample
# list of lists

# old version - I am checking only whether char to the left/right is not letter, but need also to check it not a digit!
"""
HALLUCINATED_ENTITIES = []

for sample_ind in range(len(test_outputs)):
    
    # get generated text at this index
    generated_section = test_outputs[sample_ind]
    
    # get input entities at this index
    input_entities = entities_inputs[sample_ind]
    
    curr_hallucination_entities = []
    
    # for each unique from train input entities (used in fine-tuning)
    # find out entities present in test_output but not in corresponding entities_inputs
    for entity in entities_finetuning:
        
        # tokenize entity in order to check whether it is present in text generation
        entity_token = wordpunct_tokenize(entity)
        entity_token = " ".join(entity)
        
        # input_entities and entity have same format so do not check whether entity_token in input_entities
        if entity_token in generated_section and entity not in input_entities:
            
            # make sure that it is indeed <entity> in generated_section and not a substring of a token
            # important - check that there is a whitespace around entity in curr_output
            start_entity = generated_section.index(entity_token)
            end_entity = generated_section.index(entity_token) + len(entity_token)
            
            # edge cases when entity - at the begining
            if start_entity == 0 and not generated_section[end_entity].isalpha():
                curr_hallucination_entities.append(entity_token)
            # edge cases when entity - at the end
            elif not generated_section[start_entity-1].isalpha() and end_entity >= len(generated_section):
                curr_hallucination_entities.append(entity_token)
            elif not generated_section[start_entity-1].isalpha() and not generated_section[end_entity].isalpha():
                curr_hallucination_entities.append(entity_token)
            
            # else - current entity is part of a token in generated text - do not count such entity
    
    HALLUCINATED_ENTITIES.append(curr_hallucination_entities)
"""
# Out:
# '\nHALLUCINATED_ENTITIES = []\n\nfor sample_ind in range(len(test_outputs)):\n    \n    # get generated text at this index\n    generated_section = test_outputs[sample_ind]\n    \n    # get input entities at this index\n    input_entities = entities_inputs[sample_ind]\n    \n    curr_hallucination_entities = []\n    \n    # for each unique from train input entities (used in fine-tuning)\n    # find out entities present in test_output but not in corresponding entities_inputs\n    for entity in entities_finetuning:\n        \n        # tokenize entity in order to check whether it is present in text generation\n        entity_token = wordpunct_tokenize(entity)\n        entity_token = " ".join(entity)\n        \n        # input_entities and entity have same format so do not check whether entity_token in input_entities\n        if entity_token in generated_section and entity not in input_entities:\n            \n            # make sure that it is indeed <entity> in generated_section and not a substring of a token\n            # important - check that there is a whitespace around entity in curr_output\n            start_entity = generated_section.index(entity_token)\n            end_entity = generated_section.index(entity_token) + len(entity_token)\n            \n            # edge cases when entity - at the begining\n            if start_entity == 0 and not generated_section[end_entity].isalpha():\n                curr_hallucination_entities.append(entity_token)\n            # edge cases when entity - at the end\n            elif not generated_section[start_entity-1].isalpha() and end_entity >= len(generated_section):\n                curr_hallucination_entities.append(entity_token)\n            elif not generated_section[start_entity-1].isalpha() and not generated_section[end_entity].isalpha():\n                curr_hallucination_entities.append(entity_token)\n            \n            # else - current entity is part of a token in generated text - do not count such entity\n    \n    HALLUCINATED_ENTITIES.append(curr_hallucination_entities)\n'

# %% [markdown]
# ### Calculate metrics

# %%
# each element - entities from input included in generated output
len(ENTITIES_INCLUDED)
# Out:
# 742

# %%
# each element - entities from input NOT included in generated output
len(ENTITIES_NOT_INCLUDED)
# Out:
# 742

# %%
# each element - entities from the whole train entities present in generated output but not in the corresponding input
len(HALLUCINATED_ENTITIES)
# Out:
# 742

# %%
ENTITIES_INCLUDED
# Out:
# [['incivo',
#   'the virus',
#   'hepatitis c infection',
#   'peginterferon alfa',
#   'ribavirin',
#   'telaprevir',
#   'medicines',
#   'ns3 - 4a protease inhibitors',
#   'hepatitis c virus'],
#  ['incivo',
#   'allergic',
#   'telaprevir',
#   'this medicine',
#   'peginterferon alfa',
#   'ribavirin',
#   'severe side effects',
#   '56',
#   'the medicine alfuzosin',
#   'symptoms',
#   'an enlarged prostate',
#   '1',
#   'these medicines',
#   'side effects',
#   'medicine',
#   'medicines'],
#  ['this medicine',
#   'the appropriate dose regimen',
#   'the recommended dose regimen',
#   '3',
#   '6',
#   '2',
#   '8',
#   'both hepatitis c virus infection',
#   'human immunodeficiency virus infection',
#   'efavirenz'],
#  ['incivo',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'rash',
#   'an itchy skin rash',
#   'the rash',
#   'other symptoms',
#   'a severe skin reaction',
#   'immediately',
#   'a skin rash',
#   'your rash',
#   'a rash',
#   'fever',
#   'tiredness',
#   'swelling of the face',
#   'a wide - spread rash',
#   'peeling skin',
#   'flu - like symptoms',
#   'symptoms',
#   'skin rash',
#   'lymph glands'],
#  ['incivo', 'this medicine', 'incivo tablets', 'the bottle'],
#  ['incivo',
#   'telaprevir',
#   'incivo contains',
#   '375',
#   'tablet core hypromellose acetate succinate',
#   'calcium hydrogen phosphate ( anhydrous',
#   'microcrystalline cellulose',
#   'sodium lauryl sulphate',
#   'croscarmellose sodium',
#   'sodium stearyl fumarate',
#   'film',
#   'coat polyvinyl alcohol',
#   'macrogol',
#   'talc , titanium dioxide',
#   'iron oxide yellow'],
#  ['zinbryta',
#   'daclizumab beta',
#   'a monoclonal antibody',
#   'multiple sclerosis',
#   'therapy',
#   'two ms treatment',
#   'other treatments',
#   'inflammation',
#   'the protective sheath',
#   'nerves',
#   'central nervous system',
#   'brain',
#   'spinal cord',
#   'this loss of myelin',
#   'demyelination',
#   'relapsing ms',
#   'repeated attacks ( relapses )',
#   'symptoms',
#   'relapses',
#   'treatment'],
#  ['zinbryta',
#   'previously',
#   'a serious allergic reaction',
#   'daclizumab',
#   'this medicine',
#   '6 .',
#   'liver problems',
#   'any other autoimmune disorders',
#   'any other medicines',
#   'herbal supplements',
#   'any medicines',
#   'supplements',
#   'liver side effects',
#   'these medicines',
#   'side effects',
#   '6',
#   'liver',
#   'other medicines'],
#  ['zinbryta',
#   'this medicine',
#   '150',
#   'a blood test',
#   'liver',
#   '40',
#   'this blood test'],
#  ['zinbryta',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'serious side effects',
#   'liver problems',
#   'affect',
#   '1',
#   '10',
#   'unexplained nausea ( feeling sick )',
#   'vomiting ( being sick )',
#   'stomach pain',
#   'increased tiredness loss of appetite',
#   'anorexia )',
#   'your skin',
#   'your eyes turn yellow dark ( tea - coloured ) urine',
#   '41',
#   '100',
#   'severe inflammation of the liver',
#   'death',
#   'increased tiredness',
#   'eyes'],
#  ['zinbryta',
#   'this medicine',
#   'the zinbryta pre - filled syringe',
#   'original package',
#   'a new syringe / pen',
#   'a refrigerator',
#   '30'],
#  ['zinbryta',
#   'daclizumab beta',
#   'each pre - filled syringe',
#   '150',
#   '1',
#   'sodium succinate',
#   'succinic acid',
#   'sodium chloride',
#   'polysorbate 80',
#   '2',
#   "sodium ')",
#   'slightly yellow',
#   'a syringe / pen'],
#  ['wilzin',
#   'medicines',
#   'metabolism products',
#   "wilson ' s disease",
#   'a rare inherited defect in copper excretion',
#   'liver',
#   'eyes',
#   'brain',
#   'liver damage',
#   'neurological disorders',
#   'intestine',
#   'its further accumulation in the body',
#   'this treatment'],
#  ['wilzin',
#   'allergic',
#   'hypersensitive )',
#   'zinc',
#   'wilzin wilzin',
#   'initial therapy',
#   'signs and symptoms',
#   "wilson ' s disease",
#   'currently',
#   'another anti - copper agent',
#   'penicillamine',
#   'the initial treatment',
#   'other anti - copper agents',
#   'your symptoms',
#   'the treatment',
#   'blood and urine',
#   'monitoring'],
#  ['wilzin',
#   'the different dose regimens',
#   '25',
#   '50',
#   '1',
#   '2',
#   'this medicine'],
#  ['wilzin',
#   'all medicines',
#   'side effects',
#   '1',
#   '10',
#   '100',
#   '1 , 000',
#   '10 , 000'],
#  ['25 .', 'medicines', 'these measures'],
#  ['wilzin',
#   'zinc',
#   '25',
#   '83 . 92',
#   'zinc acetate dihydrate )',
#   '50',
#   '167 . 84',
#   'zinc acetate dihydrate',
#   'magnesium stearate',
#   'the capsule shell',
#   'gelatin , titanium dioxide',
#   'brilliant blue fcf',
#   'the pack wilzin'],
#  ['bictegravir',
#   'an antiretroviral medicine',
#   'an integrase strand transfer inhibitor',
#   'emtricitabine',
#   'a nucleoside reverse transcriptase inhibitor',
#   'nrti ) tenofovir alafenamide',
#   'the treatment',
#   'human immunodeficiency virus',
#   '1',
#   'hiv',
#   'infection'],
#  ['biktarvy',
#   'allergic',
#   'bictegravir',
#   'emtricitabine',
#   'tenofovir alafenamide',
#   'this medicine',
#   'rifampicin',
#   'some bacterial infections',
#   'infections',
#   'medicines',
#   'bacterial infections'],
#  ['biktarvy',
#   'this medicine',
#   'antacids',
#   'stomach ulcers',
#   'heartburn',
#   'acid reflux',
#   'aluminium',
#   'magnesium hydroxide mineral supplements',
#   'vitamins',
#   'magnesium',
#   'iron',
#   '2',
#   'these medicines'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'immediately',
#   'inflammation',
#   'infection',
#   'advanced hiv infection',
#   'opportunistic infections ( infections',
#   'a weak immune system',
#   'symptoms',
#   'previous infections',
#   'hiv treatment',
#   'these symptoms',
#   "the body ' s immune response",
#   'fight infections',
#   'obvious symptoms',
#   'autoimmune disorders',
#   'immune system attacks',
#   'body tissue',
#   'medicines',
#   'hiv infection',
#   'treatment'],
#  ['this medicine', 'the seal'],
#  ['biktarvy',
#   'bictegravir',
#   'emtricitabine',
#   'tenofovir alafenamide',
#   '50',
#   '200',
#   '25',
#   'tablet core microcrystalline cellulose',
#   'croscarmellose sodium',
#   'magnesium stearate',
#   'film'],
#  ['novonorm',
#   'an oral antidiabetic medicine',
#   'repaglinide',
#   'pancreas',
#   'insulin',
#   'your blood sugar',
#   'glucose',
#   'type 2 diabetes',
#   '2',
#   'a disease',
#   'the sugar',
#   'body',
#   'the insulin',
#   'treatment',
#   'exercise and weight reduction',
#   'metformin',
#   'diabetes'],
#  ['novonorm',
#   'allergic',
#   'repaglinide',
#   'type 1 diabetes',
#   '1',
#   'the acid level',
#   'your blood',
#   'diabetic ketoacidosis',
#   'a severe liver disease',
#   'gemfibrozil',
#   'a medicine',
#   'lower increased fat levels',
#   '47',
#   'liver problems',
#   'moderate liver disease',
#   'diabetes'],
#  ['novonorm', 'this medicine', '0 . 5', 'swallow', '30'],
#  ['novonorm',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'hypoglycaemia',
#   '1',
#   '10',
#   'a hypo in section',
#   'generally mild / moderate',
#   'coma',
#   'allergy allergy',
#   '10 , 000',
#   'symptoms',
#   'swelling',
#   'difficulty in breathing',
#   'rapid heartbeat',
#   'feeling dizzy',
#   'sweating',
#   'anaphylactic reaction',
#   'other side effects'],
#  ['novonorm',
#   'repaglinide',
#   'microcrystalline cellulose',
#   'calcium hydrogen phosphate anhydrous',
#   'maize starch',
#   'polacrilin potassium',
#   'povidone ( polyvidone )',
#   'glycerol',
#   'magnesium stearate',
#   'meglumine',
#   'poloxamer',
#   'iron oxide yellow',
#   'iron oxide red',
#   '2'],
#  ['pumarix',
#   'a vaccine',
#   '18',
#   'pandemic flu ( influenza )',
#   'pandemic flu',
#   'influenza',
#   '10',
#   'ordinary flu',
#   'the vaccine',
#   'the disease',
#   'flu',
#   'all vaccines'],
#  ['pumarix',
#   'a sudden life - threatening allergic reaction',
#   'this vaccine',
#   '6',
#   'chicken protein',
#   'ovalbumin',
#   'formaldehyde',
#   'sodium deoxycholate',
#   'an allergic reaction',
#   'itchy skin rash',
#   'skin',
#   'shortness of breath',
#   'swelling of the face or tongue',
#   'the vaccine',
#   'medical treatment',
#   'vaccine',
#   'sodium'],
#  ['pumarix',
#   '18',
#   'a similar h5n1 as03',
#   'vaccine',
#   '3 - 9',
#   '3',
#   '10 - 17',
#   'injection',
#   'muscle',
#   'arm',
#   'this vaccine'],
#  ['pumarix',
#   'all medicines',
#   'this vaccine',
#   'side effects',
#   'allergic reactions',
#   'dangerously low blood pressure',
#   'shock',
#   'emergency treatment',
#   'affect',
#   '1',
#   '10 people pain',
#   'the injection',
#   'headache',
#   'tired aching muscles',
#   'joint pain',
#   '10',
#   'redness',
#   'swelling',
#   'fever sweating shivering diarrhoea',
#   'feeling sick',
#   '100',
#   'bruising',
#   'sick',
#   'fever',
#   'vaccine'],
#  ['this vaccine', 'the vaccine', 'the suspension', '24', '30 .'],
#  ['pumarix',
#   'split influenza virus',
#   'pr8 - ibcdc - rg2',
#   '0 . 5',
#   'haemagglutinin',
#   'the pandemic',
#   'the vaccine',
#   "an ' adjuvant ' as03",
#   'this adjuvant contains squalene',
#   'dl - α - tocopherol',
#   'polysorbate',
#   '80',
#   'adjuvants',
#   'sodium chloride',
#   'disodium hydrogen phosphate',
#   'potassium dihydrogen phosphate',
#   'water',
#   'injections'],
#  ['a radiopharmaceutical product',
#   'edotreotide',
#   'the powder',
#   'a radioactive substance called gallium ( 68ga ) chloride',
#   'this procedure',
#   'gallium',
#   'vein',
#   'body areas',
#   'a medical imaging procedure',
#   'positron emission tomography',
#   'pet',
#   'this medical procedure',
#   'images',
#   'the abnormal cells',
#   'tumours',
#   'your disease'],
#  ['allergic',
#   'edotreotide',
#   'this medicine',
#   'allergic reaction',
#   '4',
#   'kidney or liver problems',
#   'liver',
#   'renal or hepatic disease',
#   '18',
#   'dehydration',
#   'the examination',
#   '28'],
#  ['radiopharmaceutical products',
#   '29',
#   'the procedure',
#   '100',
#   '200',
#   'megabecquerel',
#   'nuclear medicine'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'allergic reactions',
#   'hypersensitivity',
#   'symptoms',
#   'warm flush',
#   'redness of the skin',
#   'swelling',
#   'itching',
#   'nausea',
#   'difficulty breathing',
#   'stinging',
#   'injection site',
#   'ionising radiation',
#   'cancer',
#   'hereditary abnormalities'],
#  ['this medicine',
#   'radiopharmaceuticals',
#   'radioactive materials',
#   'radiolabelling',
#   '4',
#   '25',
#   'radioactive products'],
#  ['edotreotide',
#   'powder',
#   '40',
#   '10 - phenanthroline',
#   'gentisic acid',
#   'mannitol',
#   'formic acid',
#   'sodium hydroxide',
#   'injections',
#   'sodium',
#   'radiolabelling',
#   'the solution',
#   'hydrochloric acid',
#   'radiopharmaceutical preparation'],
#  ['an anticancer medicine',
#   'the active substance everolimus',
#   'everolimus',
#   'the growth',
#   'cancer cells',
#   'hormone receptor',
#   'positive advanced breast cancer',
#   'postmenopausal',
#   'non - steroidal aromatase inhibitors',
#   'the disease under control',
#   'a medicine',
#   'exemestane',
#   'hormonal anticancer therapy',
#   'advanced tumours',
#   'neuroendocrine tumours',
#   'stomach',
#   'bowels',
#   'lung',
#   'pancreas'],
#  ['afinitor',
#   'cancer treatment',
#   'allergic',
#   'everolimus',
#   'sirolimus',
#   'this medicine',
#   'any problems with your liver',
#   'any disease',
#   'liver',
#   'treatment'],
#  ['afinitor',
#   'this medicine',
#   '10',
#   'liver problems',
#   '5',
#   '7 . 5',
#   'certain side effects',
#   'treatment'],
#  ['afinitor',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'an allergic reaction',
#   'difficulty breathing',
#   'swallowing swelling of the face',
#   'lips , tongue',
#   'throat severe itching of the skin',
#   'a red rash',
#   'raised bumps',
#   'affect',
#   '1',
#   '10',
#   'increased temperature',
#   'chills',
#   'infection )',
#   'fever',
#   'coughing',
#   'wheezing',
#   'inflammation of the lung',
#   'inflammation',
#   'swelling',
#   'rash',
#   'itching',
#   'swallowing',
#   'signs',
#   'swelling of the face',
#   'throat'],
#  ['this medicine', '25 .', 'open the blister', 'the tablets', 'tampering'],
#  ['afinitor',
#   'everolimus',
#   '2 . 5',
#   '5',
#   'hypromellose',
#   'crospovidone',
#   'lactose anhydrous',
#   'white to slightly yellowish'],
#  ['laventair ellipta',
#   'umeclidinium bromide',
#   'vilanterol',
#   'a group of medicines',
#   'bronchodilators',
#   'chronic obstructive pulmonary disease ( copd )',
#   'copd',
#   'a long - term condition',
#   'breathing difficulties',
#   'muscles',
#   'this medicine',
#   'tightening',
#   'lungs'],
#  ['laventair ellipta',
#   '31',
#   'allergic',
#   'umeclidinium',
#   'vilanterol',
#   'this medicine',
#   'asthma',
#   'heart problems',
#   'high blood pressure',
#   'an eye problem',
#   'narrow - angle glaucoma'],
#  ['laventair ellipta',
#   'this medicine',
#   '24',
#   'symptoms',
#   'a sudden attack of breathlessness',
#   'wheezing',
#   'attack',
#   'breathlessness'],
#  ['laventair ellipta',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'allergic reactions',
#   'the following symptoms',
#   'immediately',
#   'uncommon side effects',
#   '1',
#   '100',
#   'skin rash ( hives',
#   'redness rare side effects',
#   '1 , 000',
#   'swelling',
#   'face',
#   'mouth',
#   'angioedema',
#   'very wheezy',
#   'coughing',
#   'difficulty in breathing',
#   'feeling weak',
#   'light headed',
#   'collapse',
#   'loss of consciousness',
#   'immediate breathing difficulties',
#   '10',
#   'rare side effects'],
#  ['laventair ellipta',
#   'umeclidinium bromide',
#   'vilanterol',
#   '55',
#   'umeclidinium',
#   '65',
#   '22',
#   'trifenatate',
#   'lactose monohydrate',
#   '2',
#   "lactose '",
#   'magnesium stearate'],
#  ['tremfya',
#   'guselkumab',
#   'a monoclonal antibody',
#   'this medicine',
#   'il - 23',
#   'psoriasis',
#   'an inflammatory condition',
#   'skin',
#   'nails',
#   'improve the condition',
#   'appearance of nails'],
#  ['tremfya',
#   'allergic',
#   'guselkumab',
#   'this medicine',
#   'an active infection',
#   'active tuberculosis warnings',
#   'an infection',
#   'tuberculosis',
#   '36',
#   'symptoms',
#   'infections',
#   'allergic reactions',
#   'vaccination'],
#  ['tremfya',
#   'this medicine',
#   '100',
#   '1 pre - filled syringe )',
#   'the skin ( subcutaneous injection',
#   '4',
#   '8',
#   'injection'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'serious side effects',
#   'serious allergic reaction',
#   'difficulty breathing',
#   'swallowing',
#   'swelling of the face',
#   'lips , tongue',
#   'throat',
#   'severe itching of the skin',
#   'a red rash',
#   'raised bumps other side effects',
#   'some side effects',
#   '1',
#   '10',
#   'upper respiratory infections',
#   'allergic reaction'],
#  ['this medicine',
#   'the pre - filled syringe in the outer carton',
#   'cloudy',
#   'large particles',
#   'the pre - filled syringe',
#   '30'],
#  ['tremfya',
#   'guselkumab',
#   'each pre - filled syringe',
#   '100',
#   '1',
#   'histidine',
#   'histidine monohydrochloride monohydrate',
#   'polysorbate 80 , sucrose',
#   '80',
#   'injections',
#   'the pack solution',
#   'a carton pack',
#   'one single - dose glass syringe',
#   'a multipack containing 2',
#   '2'],
#  ['trepulmix',
#   'treprostinil',
#   'medicines',
#   'prostacyclins',
#   'hormone',
#   'blood pressure',
#   'relaxing blood vessels',
#   'blood from clotting',
#   'inoperable chronic thromboembolic pulmonary hypertension',
#   'cteph',
#   'surgical treatment',
#   'exercise capacity',
#   'symptoms',
#   'the disease',
#   'chronic thromboembolic pulmonary hypertension',
#   'blood pressure is too high',
#   'blood vessels'],
#  ['trepulmix',
#   'allergic',
#   'treprostinil',
#   'this medicine',
#   'a disease called " pulmonary veno - occlusive disease "',
#   'a disease',
#   'blood vessels',
#   'lungs',
#   'swollen',
#   'severe liver disease',
#   'a heart problem',
#   'a heart attack ( myocardial infarction',
#   'last six months',
#   'heart'],
#  ['trepulmix',
#   'this medicine',
#   'a continuous subcutaneous infusion',
#   'skin',
#   'a small tube ( cannula',
#   'abdomen',
#   'thigh',
#   'a portable pump',
#   'your treprostinil',
#   'the pump',
#   'the infusion line',
#   'accidental overdose',
#   '1',
#   '2 . 5',
#   '5',
#   'infusion',
#   'the infusion'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'affect',
#   '1',
#   '10',
#   'widening of blood vessels pain',
#   'the infusion site reaction',
#   'bruising',
#   'the infusion site',
#   'headaches',
#   'nausea',
#   'diarrhoea jaw pain',
#   'dizziness',
#   'light - headedness',
#   'fainting',
#   'low blood pressure skin rashes',
#   'muscle pain',
#   'myalgia )',
#   'joint pain',
#   'arthralgia )',
#   'swelling of feet , ankles , legs',
#   'fluid retention',
#   'hot flush pain in arms and / or legs',
#   '36',
#   '100',
#   'infusion site',
#   'skin rashes'],
#  ['trepulmix',
#   'this medicine',
#   '30',
#   'continuous subcutaneous infusion',
#   '72'],
#  ['trepulmix',
#   'treprostinil',
#   '1',
#   'sodium salt',
#   '10',
#   '2 . 5',
#   '25',
#   '5',
#   'hydrochloric acid',
#   'injections',
#   '2'],
#  ['thorinane',
#   'enoxaparin sodium',
#   'a low molecular weight heparin ( lmwh',
#   '1',
#   'existing blood clots',
#   '2',
#   'your blood',
#   'blood clots',
#   'operation',
#   'an acute illness',
#   'unstable angina',
#   'heart'],
#  ['thorinane',
#   'allergic',
#   'enoxaparin sodium',
#   'this medicine',
#   'an allergic reaction',
#   'rash',
#   'swallowing',
#   'breathing problems',
#   'swelling of your lips , face , throat or tongue',
#   'heparin',
#   'other low molecular weight heparins',
#   'nadroparin',
#   'tinzaparin',
#   'dalteparin',
#   'a reaction',
#   'a severe drop',
#   'enoxaparin',
#   'low molecular weight heparins'],
#  ['thorinane',
#   'other similar medicines',
#   'medicines',
#   'blood clotting',
#   'bleeding',
#   'any bleeding event',
#   'excessive bleeding',
#   'exceptional weakness',
#   'tiredness',
#   'paleness',
#   'dizziness',
#   'headache',
#   'unexplained swelling',
#   'immediately',
#   'your medicine',
#   'a severe allergic reaction',
#   'difficulty breathing',
#   'blockage of a blood vessel',
#   'a blood clot',
#   'cramping pain',
#   'swelling',
#   'severe allergic reaction'],
#  ['thorinane',
#   'this medicine',
#   '25',
#   'dilution the solution',
#   '8',
#   'the thorinane pre - filled syringes'],
#  ['thorinane',
#   'enoxaparin sodium',
#   '100',
#   'each pre - filled syringe',
#   '0 . 2',
#   '2 , 000',
#   'injections',
#   'colourless type i neutral glass syringe barrel',
#   'fixed needle and needle shield',
#   '2'],
#  ['senstend',
#   'lidocaine',
#   'prilocaine',
#   'local anaesthetics',
#   'lifelong premature ejaculation',
#   'head',
#   'penis',
#   'ejaculation'],
#  ['senstend',
#   'allergic',
#   'lidocaine',
#   'prilocaine',
#   'this medicine',
#   'allergy',
#   'sensitivity',
#   'local anaesthetics',
#   'a genetic disease',
#   'other condition',
#   'your red blood cells',
#   'glucose',
#   'phosphate deficiency',
#   'anaemia',
#   'methaemoglobinaemia )',
#   'medicine sensitivities',
#   'methaemoglobinaemia'],
#  ['senstend',
#   'this medicine',
#   '3',
#   '1',
#   'head',
#   'penis',
#   '24',
#   '4',
#   'the spray container',
#   'the pump mechanism',
#   'contact with eyes , nose , mouth and ears',
#   'the pump',
#   'mouth',
#   'ears'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'affect',
#   '1',
#   '10',
#   'inability to develop or maintain an erection',
#   'penis',
#   'feeling of burning',
#   '100',
#   'headache local irritation of the throat',
#   'irritation',
#   'the skin redness',
#   'failure to ejaculate during sexual intercourse',
#   'abnormal orgasm tingling',
#   'discomfort',
#   'the penis itching',
#   'a high temperature',
#   'headache',
#   'local irritation of the throat'],
#  ['this medicine',
#   '25',
#   '12',
#   'the metal container',
#   'puncture',
#   'burn',
#   'these measures'],
#  ['senstend',
#   'lidocaine',
#   'prilocaine',
#   'solution',
#   '150',
#   '50',
#   '7 . 5',
#   '2 . 5',
#   'each spray container',
#   '6 . 5',
#   '20',
#   '5',
#   'light yellow cutaneous spray',
#   '1'],
#  ['a medicine',
#   'advanced melanoma',
#   'skin cancer',
#   'adults melanoma',
#   'surgery',
#   'adjuvant therapy',
#   'advanced non - small cell lung cancer',
#   'lung cancer',
#   'advanced kidney cancer',
#   'adults classical hodgkin lymphoma',
#   'an autologous stem - cell transplant',
#   'a transplant',
#   'advanced cancer of the head and neck',
#   'adults advanced urothelial carcinoma',
#   'bladder and urinary tract cancer',
#   'nivolumab'],
#  ['opdivo',
#   'allergic',
#   'nivolumab',
#   'this medicine',
#   '6',
#   'your heart',
#   'a change in the rhythm',
#   'the heartbeat',
#   'an abnormal heart rhythm',
#   'your lungs',
#   'breathing difficulties',
#   'cough',
#   'inflammation of the lungs',
#   'pneumonitis',
#   'interstitial lung disease',
#   'diarrhoea',
#   'watery',
#   'loose or soft stools',
#   'any symptoms',
#   'inflammation',
#   'symptoms'],
#  ['opdivo',
#   '240',
#   '2',
#   '480',
#   '4',
#   'ipilimumab',
#   'the treatment',
#   'skin cancer',
#   '1',
#   'nivolumab',
#   'kilogram',
#   'your body weight',
#   'advanced kidney cancer',
#   '3',
#   'treatment'],
#  ['this medicine', '25', '48', 'the infusion solution', 'waste material'],
#  ['opdivo',
#   'nivolumab',
#   'concentrate',
#   'infusion',
#   '10',
#   '40',
#   '4',
#   '100',
#   '240',
#   '24',
#   'sodium citrate dihydrate',
#   'sodium chloride',
#   '2',
#   'mannitol ( e',
#   'pentetic acid',
#   'polysorbate 80',
#   'sodium hydroxide',
#   '1'],
#  ['a group of medicines',
#   'antiplatelet medicinal products',
#   'platelets',
#   'very small structures in the blood',
#   'blood clotting',
#   'this clumping',
#   'blood clots',
#   'thrombosis',
#   'thrombi )',
#   'hardened blood vessels ( arteries )',
#   'atherothrombotic events',
#   'stroke',
#   'heart attack',
#   'death',
#   'medicines'],
#  ['clopidogrel tad',
#   'clopidogrel',
#   '30',
#   'allergic',
#   'this medicine',
#   'a medical condition',
#   'currently',
#   'bleeding',
#   'a stomach ulcer',
#   'bleeding within the brain',
#   'severe liver disease',
#   'precautions',
#   'liver',
#   'medicine'],
#  ['this medicine',
#   'a condition',
#   "' atrial fibrillation",
#   'an irregular heartbeat',
#   '75',
#   'clopidogrel',
#   'severe chest pain',
#   'unstable angina',
#   'heart attack',
#   '300',
#   'treatment'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'immediately',
#   'fever',
#   'infection',
#   'extreme tiredness',
#   'rare decrease of some blood cells',
#   'liver problems',
#   'yellowing of the skin',
#   'eyes',
#   'jaundice',
#   'bleeding',
#   'skin',
#   'red pinpoint dots',
#   'confusion',
#   '2',
#   'swelling in the mouth',
#   'skin disorders',
#   'rashes',
#   'itching'],
#  ['clopidogrel tad',
#   'clopidogrel',
#   'each film',
#   '75',
#   'hydrochloride',
#   'microcrystalline cellulose',
#   'colloidal anhydrous silica',
#   'crospovidone',
#   'macrogol 6000 and hydrogenated castor oil',
#   '6000',
#   'polyvinyl alcohol , titanium dioxide',
#   'red iron oxide',
#   'yellow iron oxide',
#   '3000',
#   '7',
#   '30',
#   'film'],
#  ['tacforius',
#   'the active substance tacrolimus',
#   'an immunosuppressant',
#   'your organ transplant',
#   'liver',
#   'kidney',
#   "your body ' s immune system",
#   'transplanted',
#   'rejection',
#   'heart',
#   'any previous treatment',
#   'your transplantation'],
#  ['tacforius',
#   'allergic',
#   'tacrolimus',
#   'this medicine',
#   'sirolimus',
#   'any macrolide',
#   'antibiotic',
#   'erythromycin',
#   'clarithromycin',
#   'josamycin',
#   '18'],
#  ['this medicine',
#   'transplant patients',
#   'the same tacrolimus medicine',
#   'transplant',
#   'the right medicine',
#   'the rejection',
#   'your transplanted organ',
#   'transplanted',
#   'rejection'],
#  ['tacforius',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'infections',
#   'severe effects',
#   'allergic and anaphylactic reactions',
#   'benign',
#   'malignant tumours',
#   'pure red cell aplasia',
#   'a very severe reduction',
#   'red blood cell counts',
#   'agranulocytosis',
#   'a severely lowered number of white blood cells',
#   'haemolytic anaemia',
#   'decreased number of red blood cells',
#   'abnormal breakdown )',
#   'febrile neutropenia',
#   'white blood cells',
#   'blood cell counts',
#   'blood cells'],
#  ['this medicine',
#   'all the prolonged - release hard capsules',
#   '1',
#   'opening the aluminium wrapping'],
#  ['tacforius',
#   'tacrolimus',
#   '0 . 5',
#   '1',
#   '3',
#   '5',
#   'capsule content hypromellose',
#   '2910',
#   'ethylcellulose',
#   'lactose',
#   '10'],
#  ['a group of medicines',
#   'antiplatelet medicinal products',
#   'platelets',
#   'very small structures in the blood',
#   'blood clotting',
#   'this clumping',
#   'blood clots',
#   'thrombosis',
#   'thrombi )',
#   'hardened blood vessels ( arteries )',
#   'atherothrombotic events',
#   'stroke',
#   'heart attack',
#   'death',
#   'medicines'],
#  ['clopidogrel zentiva',
#   'allergic ( hypersensitive',
#   'clopidogrel',
#   'this medicine',
#   'a medical condition',
#   'currently',
#   'bleeding',
#   'a stomach ulcer',
#   'bleeding within the brain',
#   'severe liver disease',
#   'precautions',
#   'liver',
#   'zentiva',
#   'medicine'],
#  ['clopidogrel zentiva',
#   'this medicine',
#   'a condition',
#   "' atrial fibrillation",
#   'an irregular heartbeat',
#   '75',
#   'severe chest pain',
#   'unstable angina',
#   'heart attack',
#   '300',
#   '4',
#   '7'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'immediately',
#   'fever',
#   'infection',
#   'extreme tiredness',
#   'rare decrease of some blood cells',
#   'liver problems',
#   'yellowing of the skin',
#   'eyes',
#   'jaundice',
#   'bleeding',
#   'skin',
#   'red pinpoint dots',
#   'confusion',
#   '2',
#   'swelling in the mouth',
#   'skin disorders',
#   'rashes',
#   'itching'],
#  ['clopidogrel zentiva', 'this medicine', 'aluminium blisters', '30 .'],
#  ['clopidogrel zentiva',
#   'clopidogrel',
#   '75',
#   'hydrogen sulphate )',
#   '2',
#   "lactose '",
#   'mannitol',
#   'hydrogenated castor oil',
#   'microcrystalline cellulose',
#   'macrogol',
#   '6000',
#   'low - substituted hydroxypropylcellulose',
#   'lactose monohydrate ( milk sugar',
#   'hypromellose ( e',
#   '7'],
#  ['yttriga',
#   'a radioactive medicine',
#   'another medicine',
#   'tiny radiation doses',
#   'the treatment',
#   'radiolabelled medicinal product'],
#  ['yttriga',
#   'allergic',
#   'hypersensitive',
#   'chloride',
#   'pregnant',
#   'a radioactive medicine',
#   'another medicinal product',
#   'radiopharmaceuticals',
#   'radioactive material',
#   'radioactive medicinal products',
#   '2',
#   '16',
#   'other medicines',
#   'medicines'],
#  ['yttriga',
#   'the treatment',
#   'method of administration yttriga',
#   'specific diseases',
#   'overdose',
#   'appropriate treatment'],
#  ['yttriga',
#   'all medicines',
#   'side effects',
#   'any side effects',
#   'appendix v .',
#   'this medicine'],
#  ['yttriga', 'local regulations', 'radioactive substances', 'waste material'],
#  ['yttriga',
#   'chloride',
#   '1 ml sterile solution',
#   '1',
#   'hydrochloric acid',
#   '3',
#   'a colourless type i glass vial',
#   '10',
#   'a flat bottom',
#   'a silicon stopper',
#   'an aluminium seal'],
#  ['a medicine',
#   'cancer',
#   'cisplatin',
#   'another anti - cancer medicine',
#   'treatment',
#   'malignant pleural mesothelioma',
#   'lining of the lung',
#   'prior chemotherapy',
#   'the initial treatment',
#   'lung cancer',
#   'your disease',
#   'initial chemotherapy'],
#  ['ciambra',
#   'allergic',
#   'hypersensitive',
#   'pemetrexed',
#   '6',
#   'breast - feeding',
#   'treatment',
#   'a vaccine',
#   'yellow fever',
#   'problems with your kidneys',
#   'your blood',
#   'liver function'],
#  ['ciambra',
#   '500',
#   "your body ' s surface area",
#   'your height and weight',
#   'body',
#   'this body surface area',
#   'treatment',
#   'your blood cell counts',
#   '9',
#   'sodium chloride solution',
#   'infusion',
#   '5'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   '52',
#   'fever',
#   'infection',
#   'a temperature',
#   'sweating',
#   'white blood cells than normal',
#   'sepsis',
#   'death',
#   'chest pain',
#   'a fast heart rate',
#   'pain',
#   'redness',
#   'swelling',
#   'sores in your mouth',
#   'allergic reaction',
#   'sores',
#   'white blood cells',
#   'heart'],
#  ['this medicine',
#   '24 hours',
#   '2 - 8',
#   '15',
#   '25 .',
#   'the reconstituted solution',
#   'the infusion solution',
#   '24',
#   '2',
#   '8'],
#  ['ciambra',
#   'pemetrexed',
#   '100',
#   '500',
#   'reconstitution',
#   'the solution',
#   '25',
#   'further dilution',
#   'mannitol ( e',
#   '2',
#   '1'],
#  ['a group of medicines',
#   'immunoglobulins ( antibodies',
#   'certain infections',
#   'your blood',
#   'increased levels',
#   'blood plasma of screened',
#   'hepatitis b virus',
#   'haemodialysed patients',
#   'vaccination',
#   'an immune response',
#   'measurable hepatitis b antibodies',
#   'continuous prevention'],
#  ['an allergic reaction',
#   'human immunoglobulins',
#   'other blood products',
#   'an iga deficiency',
#   'iga containing products',
#   '18',
#   'immunoglobulins',
#   'adverse reactions',
#   'chills',
#   'headache',
#   'fever',
#   'vomiting',
#   'allergic reactions',
#   'nausea',
#   'arthralgia',
#   'joint pain',
#   'low blood pressure',
#   'moderate low back pain',
#   'antibodies'],
#  ['vaccination',
#   'hepatitis b virus',
#   'the first vaccine dose',
#   'human hepatitis b immunoglobulin',
#   'administration prevention',
#   'hepatitis b',
#   '500',
#   '24',
#   '72',
#   'hepatitis b in haemodialysed patients',
#   '2',
#   'seroconversion',
#   '5'],
#  ['immunogam',
#   'all medicines',
#   'side effects',
#   '1',
#   '10',
#   '100',
#   '1 , 000',
#   '10 , 000',
#   'undesirable effects',
#   'clinical trials',
#   'injection site',
#   'injection'],
#  ['immunogam',
#   'the outer carton',
#   'cloudy',
#   'deposits',
#   'medicines',
#   'these measures'],
#  ['immunogam',
#   'human hepatitis b immunoglobulin',
#   '1',
#   '5',
#   'human plasma protein',
#   '96',
#   'polysorbate',
#   '80 .',
#   'pale yellow liquid'],
#  ['the active substance infliximab',
#   'infliximab',
#   'a monoclonal antibody a type of protein',
#   'tumour necrosis factor',
#   'medicines',
#   'the following inflammatory diseases',
#   'rheumatoid arthritis',
#   'psoriatic arthritis',
#   'ankylosing spondylitis',
#   "bechterew ' s disease )",
#   'psoriasis',
#   '6'],
#  ['remicade',
#   'allergic',
#   'infliximab',
#   '6',
#   'hypersensitive',
#   'tuberculosis',
#   'tb',
#   'another serious infection',
#   'pneumonia',
#   'sepsis',
#   'heart failure',
#   'or',
#   'infection',
#   'heart',
#   'immediately'],
#  ['remicade',
#   'rheumatoid arthritis',
#   '3',
#   'body weight',
#   'psoriatic arthritis',
#   'ankylosing spondylitis',
#   "bechterew ' s disease )",
#   'psoriasis',
#   'ulcerative colitis',
#   '5',
#   'infusion',
#   'the medicine',
#   'an infusion ( drip',
#   'over 2 hours',
#   '2',
#   'veins',
#   'weight'],
#  ['remicade',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'mild to moderate',
#   'serious side effects',
#   'treatment',
#   'your treatment',
#   'an allergic reaction',
#   'swelling of your face , lips , mouth or throat',
#   'difficulty in swallowing',
#   'breathing',
#   'skin rash',
#   'hives',
#   'swelling of the hands , feet or ankles',
#   'these reactions',
#   '2',
#   'skin',
#   'swelling',
#   '1',
#   '10'],
#  ['remicade', 'this medicine', '2', '8', '25', 'infusion', '3', '28'],
#  ['remicade',
#   'what remicade',
#   'infliximab',
#   '100',
#   '10',
#   'sucrose',
#   'polysorbate 80',
#   'monobasic sodium phosphate',
#   'a glass vial',
#   'a powder',
#   'infusion',
#   'the powder',
#   '1',
#   '2',
#   '3',
#   '4',
#   '5'],
#  ['rasagiline mylan',
#   "parkinson ' s disease",
#   'levodopa',
#   'another medicine',
#   'a loss of cells',
#   'dopamine in the brain',
#   'dopamine',
#   'brain',
#   'movement control'],
#  ['rasagiline mylan',
#   'rasagiline',
#   'allergic',
#   'this medicine',
#   'severe liver problems',
#   'the following medicines',
#   'monoamine oxidase ( mao ) inhibitors',
#   'depression',
#   "parkinson ' s disease",
#   'a strong pain killer',
#   'treatment',
#   'mao inhibitors',
#   'other medicines',
#   'medicines'],
#  ['rasagiline mylan',
#   'this medicine',
#   '1',
#   'mouth',
#   'rasagiline',
#   'immediately'],
#  ['rasagiline mylan',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'placebo',
#   'frequency',
#   '1',
#   '1 , 000',
#   'very common abnormal movements ( dyskinesia )',
#   'headache',
#   'common abdominal pain',
#   'fall allergy',
#   'fever flu ( influenza )',
#   'feeling of being unwell',
#   'neck pain',
#   'chest pain',
#   'angina pectoris )',
#   'low blood pressure',
#   'symptoms',
#   'light headedness',
#   'orthostatic hypotension',
#   'decreased appetite',
#   'constipation',
#   'dry mouth',
#   'rasagiline'],
#  ['rasagiline mylan',
#   'rasagiline',
#   '1',
#   'microcrystalline cellulose',
#   'tartric acid',
#   'maize starch',
#   'pregelatinized maize starch',
#   'talc , stearic acid',
#   '11 . 5',
#   '6',
#   'biconvex tablets'],
#  ['hulio',
#   'allergic',
#   'adalimumab',
#   'this medicine',
#   'a severe infection',
#   'tuberculosis',
#   'symptoms',
#   'infections',
#   'fever',
#   'wounds',
#   'feeling tired',
#   'dental problems',
#   'moderate or severe heart failure',
#   'a serious heart condition',
#   'allergic reaction',
#   'allergic reactions',
#   'chest tightness',
#   'wheezing',
#   'dizziness',
#   'swelling',
#   'a rash',
#   'these reactions',
#   'heart failure'],
#  ['hulio',
#   'this medicine',
#   'polyarticular juvenile idiopathic arthritis',
#   '2',
#   '17',
#   '10',
#   '30',
#   '20',
#   '40',
#   'enthesitis',
#   'arthritis',
#   '6',
#   '15',
#   '4',
#   '2 to 17',
#   '7'],
#  ['hulio',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'mild to moderate',
#   'urgent medical treatment',
#   '4',
#   'the last hulio injection',
#   'allergic reaction',
#   'heart failure',
#   'severe rash',
#   'hives swollen face , hands or feet',
#   'trouble breathing',
#   'swallowing',
#   'pale complexion',
#   'dizziness',
#   'persistent fever',
#   'bruising',
#   'bleeding',
#   'signs and symptoms',
#   'infection',
#   'fever',
#   'feeling sick',
#   'wounds',
#   'dental problems',
#   'burning on urination',
#   'feeling weak',
#   'tired',
#   'symptoms',
#   'heart'],
#  ['hulio',
#   'adalimumab',
#   'monosodium glutumate',
#   'sorbitol',
#   'methionine',
#   'polysorbate 80',
#   'hydrochloric acid',
#   'injections',
#   '40',
#   'a sterile solution',
#   '0 . 8',
#   'slightly opalescent',
#   'a rubber stopper',
#   '1',
#   '2',
#   '1 sterile injection syringe'],
#  ['yellox',
#   'bromfenac',
#   'medicines',
#   'non - steroidal anti - inflammatory drugs',
#   'nsaids',
#   'inflammation',
#   'eye inflammation',
#   'cataract surgery'],
#  ['yellox',
#   'allergic',
#   'bromfenac',
#   'this medicine',
#   'asthma',
#   'skin allergy',
#   'intense inflammation in your nose',
#   'other nsaids',
#   'nsaids',
#   'acetylsalicylic acid',
#   'ibuprofen',
#   'ketoprofen',
#   'diclofenac',
#   'topical steroids',
#   'cortisone',
#   'unwanted side effects',
#   'bleeding problems',
#   'haemophilia',
#   'in the past'],
#  ['yellox',
#   'this medicine',
#   'eye ( s )',
#   '2',
#   'the drops',
#   'next day',
#   'your cataract surgery',
#   'method of administration yellox',
#   'your hands',
#   'the eye drops',
#   'the bottle cap',
#   'the bottle',
#   'thumb',
#   'fingers',
#   'head',
#   'eyelid',
#   'eye'],
#  ['yellox',
#   'bromfenac',
#   'solution',
#   'sodium sesquihydrate',
#   '33',
#   'boric acid',
#   'borax',
#   'sodium sulphite anhydrous',
#   'benzalkonium chloride',
#   'tyloxapol',
#   'povidone ( k30 )',
#   'disodium edetate',
#   'sodium hydroxide',
#   'acidity levels',
#   'a clear yellow liquid ( solution )'],
#  ['dzuveo',
#   'sufentanil',
#   'strong painkillers',
#   'opioids',
#   'sudden moderate - to - severe pain'],
#  ['dzuveo',
#   'allergic',
#   'sufentanil',
#   'this medicine',
#   'a serious lung or breathing problem',
#   'any condition',
#   'your breathing',
#   'asthma',
#   'wheezing',
#   'shortness of breath',
#   'treatment',
#   'a head injury',
#   'brain tumour',
#   'your heart and circulation',
#   'slow heart rate',
#   'irregular heartbeat',
#   'low blood volume'],
#  ['dzuveo',
#   'this medicine',
#   'the single - dose administration device',
#   'strong painkillers',
#   'sufentanil',
#   '30',
#   'the sublingual tablet',
#   'the applicator',
#   'tongue',
#   'the tablets dissolve'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'serious side effects',
#   'severe breathing problems',
#   'slow and shallow breathing',
#   'immediately',
#   'very common side effects',
#   'affect',
#   '1',
#   'in 10 people',
#   '10',
#   'nausea',
#   'feeling sick',
#   'vomiting',
#   'being sick',
#   'feeling hot',
#   'common side effects',
#   'inability or difficulty sleeping',
#   'feeling anxious',
#   'confused',
#   'dizziness',
#   'headache',
#   'drowsiness',
#   'feeling sleepy'],
#  ['this medicine', 'deterioration', 'medicines'],
#  ['dzuveo',
#   'sufentanil',
#   '30',
#   'citrate',
#   'mannitol',
#   'dicalcium phosphate',
#   'hypromellose',
#   'croscarmellose sodium',
#   'indigo carmine',
#   'stearic acid',
#   'magnesium stearate',
#   '3'],
#  ['erleada',
#   'a cancer medicine',
#   'apalutamide',
#   'prostate cancer',
#   'body',
#   'surgical treatments',
#   'sensitive prostate cancer',
#   'testosterone',
#   'resistant prostate cancer',
#   'androgens',
#   'the cancer',
#   'prostate cancer cells'],
#  ['erleada',
#   'allergic',
#   'apalutamide',
#   'this medicine',
#   'pregnant',
#   'pregnancy',
#   'contraception section',
#   'seizures',
#   'any medicines',
#   'blood clots',
#   'warfarin',
#   'acenocoumarol',
#   'any heart or blood vessel conditions',
#   'heart rhythm problems',
#   'medicines',
#   'contraception'],
#  ['erleada', 'this medicine', '240', '60', 'mouth', 'other medicines', 'the'],
#  ['erleada',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'the following symptoms',
#   'reddish',
#   'non - elevated',
#   'target - like',
#   'circular patches on the trunk',
#   'central blisters',
#   'skin peeling',
#   'ulcers of mouth , throat , nose , genitals and eyes',
#   'these serious skin rashes',
#   'fever',
#   'flu - like symptoms',
#   'toxic epidermal necrolysis',
#   'serious side effects',
#   'seizure',
#   'symptoms',
#   'blisters',
#   'peeling'],
#  ['erleada',
#   'apalutamide',
#   'each film',
#   '60',
#   'colloidal anhydrous silica',
#   'croscarmellose sodium',
#   'hypromellose acetate succinate',
#   'magnesium stearate',
#   'microcrystalline cellulose',
#   'the film',
#   'iron oxide black',
#   'iron oxide yellow',
#   'macrogol',
#   'polyvinyl alcohol',
#   'talc , and titanium dioxide',
#   '6'],
#  ['axumin',
#   'a radiopharmaceutical product',
#   'the active ingredient fluciclovine',
#   'scan',
#   'a pet scan',
#   'previously',
#   'treatment',
#   'prostate cancer',
#   'other tests',
#   'prostate specific antigen',
#   'psa',
#   'the cancer',
#   'an axumin pet scan',
#   'the scan'],
#  ['axumin',
#   'allergic',
#   'fluciclovine',
#   'this medicine',
#   'kidney problems',
#   'a low sodium diet',
#   'a day',
#   'the axumin scan',
#   '4',
#   'the scan',
#   'your usual medicines',
#   'latest 60 minutes',
#   '60',
#   'sodium'],
#  ['axumin',
#   'radiopharmaceutical products',
#   'this medicine',
#   'the procedure',
#   '370',
#   'megabecquerel',
#   'the procedure axumin',
#   'vein',
#   'body'],
#  ['axumin',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'clinical studies',
#   '1',
#   '100',
#   'the medicine',
#   'pain',
#   'rash',
#   'altered taste in the mouth',
#   'altered sense of smell',
#   'this radiopharmaceutical',
#   'ionising radiation',
#   'cancer',
#   'hereditary abnormalities'],
#  ['axumin', 'this medicine', 'radiopharmaceuticals', 'radioactive materials'],
#  ['axumin',
#   'fluciclovine',
#   '1600',
#   '16000',
#   '3200',
#   '32000',
#   'sodium citrate',
#   'concentrated hydrochloric acid',
#   'sodium hydroxide',
#   '2',
#   '1'],
#  ['azopt',
#   'brinzolamide',
#   'a group of medicines',
#   'carbonic anhydrase inhibitors',
#   'pressure within the eye',
#   'azopt eye drops',
#   'high pressure in the eye',
#   'an illness',
#   'glaucoma',
#   'the pressure',
#   'eye',
#   'damage',
#   'sight'],
#  ['azopt',
#   'severe kidney problems',
#   'allergic',
#   'brinzolamide',
#   'this medicine',
#   'medicines',
#   'sulphonamides',
#   'diabetes',
#   'infections',
#   'diuretics ( water tablets',
#   'the same allergy',
#   'too much acidity',
#   'your blood',
#   'hyperchloraemic acidosis'],
#  ['azopt',
#   'this medicine',
#   'eyes',
#   '1',
#   '2',
#   'the azopt bottle',
#   'hands',
#   'the cap',
#   'snap collar',
#   'the bottle',
#   'finger',
#   'head',
#   'back',
#   'eyelid',
#   'a clean finger',
#   "a ' pocket ' between the eyelid"],
#  ['azopt',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'common side effects',
#   '1',
#   '10',
#   'eye',
#   'blurred vision',
#   'eye irritation',
#   'eye pain',
#   'eye discharge',
#   'itchy eye',
#   'dry eye',
#   'abnormal eye sensation',
#   'redness of the eye',
#   'bad taste',
#   'uncommon side effects',
#   '100',
#   'sensitivity to light',
#   'inflammation',
#   'infection',
#   'the conjunctiva',
#   'eye swelling',
#   'eyelid itching',
#   'redness',
#   'swelling',
#   'pain',
#   'itching'],
#  ['this medicine', 'infections', 'a pack containing a single bottle'],
#  ['azopt',
#   'brinzolamide',
#   '10',
#   'benzalkonium chloride',
#   'carbomer 974p',
#   'edetate disodium',
#   'mannitol',
#   'purified water',
#   'sodium chloride',
#   'tyloxapol',
#   'hydrochloric acid',
#   'sodium hydroxide',
#   'acidity levels',
#   'ph levels',
#   'the pack azopt',
#   'a milky liquid ( a suspension )',
#   '5',
#   'a screw cap'],
#  ['forxiga',
#   'dapagliflozin',
#   'medicines',
#   'mouth',
#   'diabetes',
#   'your blood',
#   '18',
#   'type 1 diabetes',
#   '1',
#   'body',
#   'any insulin',
#   'overweight',
#   'obese',
#   'type 2 diabetes',
#   '2',
#   'insulin',
#   'the insulin'],
#  ['forxiga',
#   'allergic',
#   'dapagliflozin',
#   'this medicine',
#   'feeling sick',
#   'sick',
#   'stomach pain',
#   'excessive thirst',
#   'fast and deep breathing',
#   'confusion',
#   'unusual sleepiness',
#   'tiredness',
#   'sweet smell to your breath',
#   'odour to your urine',
#   'sweat',
#   'rapid weight loss',
#   'your urine',
#   'immediately',
#   'pain'],
#  ['forxiga',
#   'this medicine',
#   'type 2 diabetes',
#   '2',
#   '10',
#   '5',
#   'a liver problem',
#   'type 1 diabetes',
#   '1',
#   'this medicine swallow',
#   'your blood'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'angioedema',
#   '1',
#   '10 , 000',
#   'swelling of the face , tongue or throat',
#   'difficulties swallowing',
#   'hives',
#   'breathing problems',
#   'diabetic ketoacidosis',
#   '10',
#   'type 2 diabetes',
#   '2',
#   '1 , 000',
#   'blood',
#   'sick',
#   'stomach pain',
#   'excessive thirst',
#   'fast and deep breathing',
#   'confusion',
#   'affect',
#   'your blood'],
#  ['forxiga',
#   'dapagliflozin',
#   '5',
#   'film - coated tablet ( tablet )',
#   'microcrystalline cellulose',
#   'lactose',
#   '2',
#   "lactose '",
#   'crospovidone',
#   'silicon dioxide',
#   'magnesium stearate',
#   'film',
#   'polyvinyl alcohol',
#   'titanium dioxide'],
#  ['mepact',
#   'certain bacteria',
#   'immune system',
#   'osteosarcoma ( bone cancer',
#   '2 and 30 years',
#   '30',
#   'surgery',
#   'remove the tumour',
#   'chemotherapy',
#   'cancer cells',
#   'cancer',
#   'back'],
#  ['mepact',
#   'allergic',
#   'mifamurtide',
#   'this medicine',
#   'medicines',
#   'ciclosporin',
#   'other calcineurin inhibitors',
#   'non - steroidal - anti - inflammatory drugs',
#   'nsaids',
#   'your heart or blood vessels',
#   'blood clots ( thrombosis )',
#   'bleeding ( haemorrhage',
#   'inflammation of the veins ( vasculitis )',
#   'precautions',
#   'treatment'],
#  ['mepact',
#   'this medicine',
#   '2',
#   'mifamurtide',
#   '12',
#   '24',
#   'your chemotherapy schedule',
#   'your chemotherapy',
#   '36',
#   '1'],
#  ['mepact',
#   'all medicines',
#   'side effects',
#   'chills',
#   'fever',
#   'fatigue',
#   'transient',
#   'paracetamol',
#   'treatment',
#   'stomach problems',
#   'nausea',
#   'vomiting',
#   'loss of appetite',
#   'chemotherapy',
#   'immediately',
#   'continuing fever',
#   'an infection',
#   'rash',
#   'any problems breathing',
#   'wheezing',
#   'any stomach problems',
#   'very common side effects',
#   'affect',
#   'common side effects',
#   'infection'],
#  ['this medicine',
#   'reconstituted suspension',
#   'sodium chloride',
#   '9',
#   '6',
#   'deterioration'],
#  ['mepact',
#   'mifamurtide',
#   '4',
#   'reconstitution',
#   'suspension',
#   '0 . 08',
#   'the other ingredients',
#   '2'],
#  ['mirvaso',
#   'the active substance brimonidine',
#   'a group of medicines',
#   'alpha agonists',
#   'skin',
#   'face',
#   'redness',
#   'rosacea',
#   'redness of the face',
#   'mirvaso acts',
#   'blood vessels',
#   'the excess blood flow'],
#  ['mirvaso',
#   'allergic',
#   'brimonidine',
#   'this medicine',
#   '6',
#   '2',
#   'side effects',
#   'the medicine',
#   'skin',
#   'certain medicines',
#   'depression',
#   "parkinson ' s disease",
#   'monoamine oxidase ( mao ) inhibitors',
#   'selegiline',
#   'moclobemide',
#   'tricyclic antidepressants',
#   'imipramine',
#   'medicines'],
#  ['mirvaso',
#   'this medicine',
#   'skin',
#   'face',
#   'body',
#   'body surfaces',
#   'your eyes , mouth , nose or vagina',
#   'the treatment',
#   'a small amount of gel ( a pea - sized amount',
#   'your symptoms',
#   'treatment',
#   'nose'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'uncommon side effects',
#   'severe skin irritation',
#   'inflammation',
#   'skin rash',
#   'skin pain',
#   'discomfort',
#   'dry skin',
#   'warm skin sensation',
#   'skin',
#   'tingling',
#   'sensation of pins and needles or swelling',
#   'worsening of rosacea',
#   'the treatment',
#   'symptoms',
#   '2',
#   'contact allergy',
#   'allergic reaction',
#   'rash',
#   'rare angioedema',
#   'a serious allergic reaction',
#   'swelling',
#   'face',
#   'mouth',
#   'tongue',
#   'affect',
#   '1',
#   '10'],
#  ['this medicine', 'tube and pump'],
#  ['mirvaso',
#   'brimonidine',
#   'gel',
#   '3 . 3',
#   '5',
#   'brimonidine tartrate',
#   'carbomer',
#   'methylparahydroxybenzoate',
#   'phenoxyethanol',
#   'glycerol , titanium dioxide',
#   'propylene glycol',
#   'sodium hydroxide',
#   'purified water',
#   '2'],
#  ['the active substance bevacizumab',
#   'a humanised monoclonal antibody',
#   'immune system',
#   'infection',
#   'cancer',
#   'human vascular endothelial growth factor',
#   'lymph vessels',
#   'blood vessels',
#   'oxygen',
#   'bevacizumab',
#   'tumour growth'],
#  ['mvasi',
#   'this medicine',
#   'allergic',
#   'hypersensitive',
#   'bevacizumab',
#   '6',
#   'hypersensitive )',
#   'chinese hamster ovary ( cho ) cell products',
#   'pregnant'],
#  ['mvasi',
#   'administration',
#   'your body weight',
#   'cancer',
#   '5',
#   '7 . 5',
#   '10',
#   '15',
#   '2 or 3 weeks',
#   '3',
#   'infusions',
#   'this medicine'],
#  ['mvasi',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'the side effects',
#   'chemotherapy',
#   'these side effects',
#   'allergic reactions',
#   'an allergic reaction',
#   'difficulty in breathing',
#   'chest pain',
#   'redness',
#   'flushing of the skin',
#   'a rash',
#   'chills',
#   'shivering',
#   'feeling sick',
#   'nausea',
#   'being sick ( vomiting )',
#   'severe side effects',
#   'affect',
#   '1',
#   'vomiting',
#   'pain',
#   'skin',
#   'rash'],
#  ['this medicine',
#   '2',
#   '8',
#   'the outer carton',
#   'infusion solutions',
#   '24',
#   'a sterile environment',
#   'dilution'],
#  ['mvasi',
#   'bevacizumab',
#   '25',
#   '1 . 4',
#   '16 . 5',
#   '4',
#   '100',
#   '16',
#   '400',
#   'trehalose dihydrate',
#   'sodium phosphate',
#   'polysorbate',
#   '20',
#   'injections'],
#  ['a gene therapy medicine',
#   'mantle cell lymphoma',
#   'other medicines',
#   'your own white blood cells',
#   'autologous anti - cd19 - transduced cd3 + cells',
#   'a cancer',
#   'immune system',
#   'b - lymphocytes',
#   'blood',
#   'body'],
#  ['tecartus',
#   'allergic',
#   'this medicine',
#   '6',
#   'white blood cells',
#   'your blood ( lymphodepleting chemotherapy',
#   '3',
#   'autologous use',
#   'tests',
#   'checks',
#   'lungs',
#   'heart',
#   'kidney',
#   'blood pressure',
#   'infection',
#   'inflammation',
#   'your cancer',
#   'graft - versus - host disease',
#   'your blood',
#   'lymphodepleting chemotherapy',
#   'blood cells'],
#  ['your own white blood cells',
#   'your cells',
#   'catheter placed',
#   'vein',
#   'a procedure call leukapheresis',
#   'your blood',
#   '3',
#   '6',
#   '2',
#   'medicines',
#   'tecartus treatment',
#   'lymphodepleting chemotherapy'],
#  ['tecartus',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'your side effects',
#   'urgent medical attention',
#   'the tecartus infusion',
#   'affect',
#   '1',
#   '10',
#   'fever',
#   'chills',
#   'reduced blood pressure',
#   'symptoms',
#   'dizziness',
#   'lightheadedness',
#   'fluid in the lungs',
#   'all symptoms',
#   'a condition',
#   'cytokine release syndrome',
#   'loss of consciousness',
#   'decreased level of consciousness',
#   'confusion',
#   'memory loss',
#   'fluid'],
#  ['this medicine',
#   'infusion bag',
#   'liquid nitrogen',
#   '150',
#   'genetically modified human blood cells',
#   'human - derived material',
#   '36'],
#  ['tecartus',
#   'autologous anti - cd19 - transduced cd3 + cells',
#   'specific single infusion bag',
#   'a dispersion of anti - cd19 car t cells',
#   '68',
#   '2',
#   '106',
#   'anti',
#   'sodium chloride',
#   'human albumin',
#   'infusion',
#   'an infusion bag'],
#  ['the active substance sitagliptin',
#   'medicines',
#   'dpp - 4 inhibitors',
#   'blood sugar levels',
#   'type 2 diabetes mellitus',
#   '2',
#   'this medicine',
#   'the levels of insulin',
#   'your blood sugar',
#   'certain other medicines',
#   'insulin',
#   'metformin',
#   'sulphonylureas',
#   'type 2 diabetes'],
#  ['januvia',
#   'allergic',
#   'sitagliptin',
#   'this medicine',
#   'inflammation of the pancreas',
#   'pancreatitis',
#   '4',
#   'blistering of the skin',
#   'bullous pemphigoid',
#   'gallstones'],
#  ['januvia',
#   'this medicine',
#   '100',
#   'coated tablet',
#   '63',
#   'mouth',
#   'kidney problems',
#   '25',
#   '50',
#   'blood sugar'],
#  ['januvia',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'immediately',
#   'severe and persistent pain in the abdomen ( stomach area',
#   'back',
#   'nausea',
#   'vomiting',
#   'an inflamed pancreas',
#   'pancreatitis',
#   'a serious allergic reaction',
#   'frequency',
#   'rash',
#   'hives',
# ...
#   'hardened blood vessels ( arteries )',
#   'atherothrombotic events',
#   'stroke',
#   'heart attack',
#   'death',
#   'medicines'],
#  ['clopidogrel mylan',
#   '31',
#   'allergic',
#   'clopidogrel',
#   'this medicine',
#   'a medical condition',
#   'currently',
#   'bleeding',
#   'a stomach ulcer',
#   'bleeding within the brain',
#   'severe liver disease',
#   'within the',
#   'liver',
#   'medicines',
#   'medicine'],
#  ['clopidogrel mylan',
#   'this medicine',
#   'a condition',
#   "' atrial fibrillation",
#   'an irregular heartbeat',
#   '75',
#   'severe chest pain',
#   'unstable angina',
#   'heart attack',
#   '300',
#   'clopidogrel',
#   '7'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'immediately',
#   'fever',
#   'infection',
#   'extreme tiredness',
#   'rare decrease of some blood cells',
#   'liver problems',
#   'yellowing of the skin',
#   'eyes',
#   'jaundice',
#   'bleeding',
#   'skin',
#   'red pinpoint dots',
#   'confusion',
#   '2',
#   'swelling in the mouth',
#   'skin disorders',
#   'rashes',
#   'itching'],
#  ['clopidogrel mylan',
#   'what clopidogrel mylan',
#   'clopidogrel',
#   'each film',
#   '75',
#   'hydrochloride',
#   'microcrystalline cellulose',
#   'colloidal anhydrous silica',
#   'crospovidone ( type a )',
#   'macrogol 6000 , hydrogenated castor oil',
#   '6000',
#   '2',
#   'polyvinyl alcohol , titanium dioxide',
#   'red iron oxide',
#   'yellow iron oxide',
#   'talc',
#   'macrogol',
#   '3000 .',
#   '7',
#   '30',
#   'film'],
#  ['doptelet',
#   'a group of medicines',
#   'thrombopoietin receptor agonists',
#   'chronic liver disease',
#   'low platelet count',
#   'a medical procedure',
#   'bleeding',
#   'platelets',
#   'blood cells',
#   'the blood to clot'],
#  ['doptelet',
#   'allergic',
#   'avatrombopag',
#   'this medicine',
#   'blood clots',
#   'veins',
#   'arteries',
#   'cancer',
#   'the contraceptive birth control pill',
#   'hormone replacement therapy',
#   'recently',
#   'surgery',
#   'injured',
#   '23',
#   'overweight',
#   'advanced chronic liver disease'],
#  ['doptelet',
#   'this medicine',
#   'your procedure',
#   '5',
#   '8',
#   '20',
#   '40',
#   '60',
#   'your platelet counts'],
#  ['doptelet',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'affect',
#   '1',
#   '10',
#   'feeling tired',
#   '100',
#   'low red blood cell count',
#   'anaemia )',
#   'blood clot in the portal vein',
#   'blood vessel',
#   'liver',
#   'intestines',
#   'upper abdominal pain',
#   'swelling bone pain',
#   'muscle aches',
#   'fever'],
#  ['doptelet',
#   'avatrombopag',
#   'each film',
#   '20',
#   'lactose monohydrate',
#   '2',
#   'microcrystalline cellulose',
#   'crospovidone type b [ e',
#   'silica , colloidal anhydrous',
#   'magnesium stearate',
#   'vinyl alcohol',
#   'talc',
#   'macrogol 3350',
#   'titanium dioxide',
#   'iron oxide yellow'],
#  ['rapiscan',
#   'medicines',
#   "' coronary vasodilators",
#   'heart arteries',
#   'heart rate',
#   'muscles',
#   'heart',
#   'heart scan',
#   "' myocardial perfusion imaging",
#   'the scan',
#   'a radioactive substance',
#   "a ' radiopharmaceutical '",
#   'these images',
#   'a scan',
#   'body',
#   'vein',
#   'hand',
#   'images',
#   'arteries'],
#  ['rapiscan',
#   'slow heart rate',
#   'heart',
#   'high degree heart block',
#   'sinus node disease',
#   'a pacemaker',
#   'chest pain',
#   'unstable angina )',
#   'treatment',
#   'low blood pressure',
#   'hypotension',
#   'heart failure',
#   'allergic',
#   'regadenoson',
#   '6',
#   'a recent serious heart problem',
#   'a heart attack',
#   'abnormal heart rhythms',
#   'a heart rhythm',
#   'heartbeat is very fast or uneven',
#   'atrial flutter',
#   'recent',
#   'heart block'],
#  ['your heart',
#   'blood pressure',
#   'vein',
#   '400',
#   'a 5 ml solution the injection',
#   '5',
#   '10',
#   'your weight',
#   'an injection of sodium chloride',
#   '9',
#   'a radioactive substance ( radiopharmaceutical',
#   'heart',
#   'injection'],
#  ['rapiscan',
#   'all medicines',
#   'side effects',
#   'the side effects',
#   '30',
#   'any treatment',
#   'sudden stopping of the heart',
#   'damage to the heart',
#   'heart block',
#   'rapid heart beat low blood pressure',
#   'fainting',
#   'weakness of the face',
#   'inability to speak',
#   'heart',
#   'rapid heart beat',
#   'the heart'],
#  ['viagra',
#   'the active substance sildenafil',
#   'a group of medicines',
#   'phosphodiesterase type 5 ( pde5 ) inhibitors',
#   '5',
#   'blood vessels',
#   'penis',
#   'erection',
#   'sexually stimulated',
#   'a treatment',
#   'erectile dysfunction',
#   'impotence',
#   'cannot get',
#   'erect penis suitable for sexual activity'],
#  ['viagra',
#   'allergic',
#   'sildenafil',
#   'this medicine',
#   'medicines',
#   'nitrates',
#   'a dangerous fall',
#   'your blood pressure',
#   'these medicines',
#   'angina pectoris',
#   '" chest pain',
#   'the medicines',
#   'immediately',
#   'other medicines',
#   'chest pain'],
#  ['viagra',
#   'this medicine',
#   '50',
#   'viagra film',
#   'coated tablets',
#   'swallow',
#   'erection',
#   'sexually stimulated'],
#  ['viagra',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'the side effects',
#   'an allergic reaction',
#   'affect',
#   '1',
#   '100',
#   'symptoms',
#   'sudden wheeziness',
#   'difficulty in breathing',
#   'dizziness',
#   'swelling of the eyelids , face , lips or throat',
#   'chest pains',
#   'a semi - sitting position',
#   'nitrates',
#   'your chest pain',
#   'prolonged and sometimes painful erections',
#   '1 , 000',
#   '10',
#   'swelling'],
#  ['viagra',
#   'sildenafil',
#   '25',
#   'the citrate salt )',
#   'microcrystalline cellulose',
#   'calcium hydrogen phosphate ( anhydrous',
#   'croscarmellose sodium',
#   'magnesium stearate',
#   'hypromellose , titanium dioxide ( e',
#   'lactose monohydrate',
#   'triacetin',
#   'indigo carmine aluminium lake',
#   'the pack viagra film',
#   'a rounded - diamond shape',
#   '2'],
#  ['sifrol',
#   'the active substance pramipexole',
#   'a group of medicines',
#   'dopamine agonists',
#   'brain',
#   'the dopamine receptors',
#   'the symptoms',
#   "primary parkinson ' s disease",
#   'levodopa',
#   "parkinson ' s disease",
#   'moderate to severe primary restless legs syndrome'],
#  ['sifrol',
#   'allergic',
#   'pramipexole',
#   'this medicine',
#   'any medical conditions',
#   'symptoms',
#   'kidney disease',
#   'hallucinations',
#   'hearing or feeling things',
#   'most hallucinations',
#   'dyskinesia',
#   'abnormal , uncontrolled movements of the limbs )',
#   "advanced parkinson ' s disease",
#   'levodopa',
#   'limbs',
#   "parkinson ' s disease"],
#  ['sifrol',
#   'this medicine',
#   "parkinson ' s disease",
#   '3',
#   'first week',
#   '1',
#   '0 . 088',
#   '0 . 264',
#   'your symptoms',
#   'tablets',
#   '2',
#   'during the',
#   '4',
#   '6'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'evaluation',
#   'these side effects',
#   'affect',
#   '1',
#   '10',
#   '100',
#   '1 , 000',
#   '10 , 000',
#   "parkinson ' s disease",
#   'dyskinesia',
#   'abnormal , uncontrolled movements of the limbs )',
#   'dizziness',
#   'nausea ( sickness )',
#   'urge to behave in an unusual way - hallucinations',
#   'hallucinations'],
#  ['sifrol',
#   'pramipexole',
#   '0 . 088',
#   '0 . 18',
#   '0 . 35',
#   '0 . 7',
#   '0 . 125',
#   'mannitol',
#   'maize starch',
#   'anhydrous colloidal silica',
#   '10',
#   '3',
#   '100'],
#  ['emadine',
#   'a medicine',
#   'the treatment',
#   'seasonal allergic conjunctivitis of the eye',
#   'allergic conditions',
#   'eye',
#   'the allergic reaction',
#   'allergic conjunctivitis',
#   'some materials ( allergens',
#   'allergic reactions',
#   'itching',
#   'redness',
#   'swelling',
#   'feel worse'],
#  ['emadine',
#   'allergic',
#   'emedastine',
#   'this medicine',
#   '3',
#   'benzalkonium chloride',
#   'clinical trials'],
#  ['emadine',
#   'eye',
#   'this medicine',
#   'eyes',
#   '1',
#   '2',
#   'the emadine bottle',
#   'hands',
#   'the bottle'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'the drops',
#   'common side effects',
#   'affect',
#   '10',
#   'eye',
#   'eye pain',
#   'itchy eye',
#   'eye redness',
#   'uncommon side effects',
#   '1',
#   '100',
#   'corneal disorder',
#   'abnormal eye sensation',
#   'increased tear production',
#   'tired eyes',
#   'eye irritation',
#   'blurred vision'],
#  ['emadine', '25 .', 'infections'],
#  ['emadine',
#   'emadastine',
#   '0 . 5',
#   'difumarate',
#   'benzalkonium chloride',
#   'trometamol',
#   'sodium chloride',
#   'hypromellose',
#   'purified water',
#   'hydrochloric acid',
#   'sodium hydroxide',
#   'acidity levels',
#   'ph levels',
#   'a liquid ( a solution )',
#   '5',
#   'a screw cap'],
#  ['an antiepileptic medicine',
#   'a medicine',
#   'seizures',
#   'epilepsy',
#   '16',
#   'newly diagnosed epilepsy',
#   'repeated fits ( seizures )',
#   'the epilepsy',
#   'brain',
#   'sides',
#   'partial onset seizure',
#   'secondary generalisation )'],
#  ['levetiracetam actavis',
#   'allergic',
#   'levetiracetam',
#   'pyrrolidone derivatives',
#   'this medicine',
#   'kidney problems',
#   'any slow down in the growth',
#   'puberty',
#   'anti - epileptics',
#   'thoughts of harming',
#   'killing themselves'],
#  ['levetiracetam actavis',
#   'this medicine',
#   'in the morning',
#   'monotherapy dose',
#   '16',
#   '1 , 000',
#   '2',
#   'levetiracetam',
#   '6'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'emergency department',
#   'weakness',
#   'light - headed',
#   'dizzy',
#   'difficulty breathing',
#   'a serious allergic ( anaphylactic ) reaction',
#   'swelling of the face , lips , tongue and throat',
#   "quincke ' s oedema",
#   'flu - like symptoms',
#   'a rash on the face',
#   'an extended rash',
#   'a high temperature',
#   'increased levels of liver enzymes',
#   'blood tests',
#   'white blood cell',
#   '56',
#   'symptoms',
#   'rash'],
#  ['levetiracetam actavis',
#   'levetiracetam',
#   '250',
#   '500',
#   '750',
#   '1 , 000',
#   '50',
#   'film',
#   '1'],
#  ['incruse ellipta',
#   'the active substance umeclidinium bromide',
#   'bronchodilators',
#   'this medicine',
#   'chronic obstructive pulmonary disease ( copd )',
#   'copd',
#   'a long - term condition',
#   'lungs',
#   'breathing difficulties',
#   'your breathing difficulties',
#   'ellipta'],
#  ['incruse ellipta',
#   '27',
#   'allergic',
#   'umeclidinium',
#   'this medicine',
#   'asthma',
#   'heart problems',
#   'an eye problem',
#   'narrow - angle glaucoma',
#   'an enlarged prostate',
#   'difficulty passing urine'],
#  ['incruse ellipta',
#   'this medicine',
#   '24',
#   'symptoms',
#   'a sudden attack of breathlessness',
#   'attack',
#   'breathlessness'],
#  ['incruse ellipta',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'allergic reactions',
#   '1',
#   '100',
#   'the following symptoms',
#   'itching skin rash',
#   'hives',
#   'redness',
#   '29',
#   '10',
#   'faster heart beat painful',
#   'frequent urination',
#   'a urinary tract infection',
#   'common cold infection of nose',
#   'throat cough',
#   'feeling of pressure',
#   'pain in the cheeks and forehead',
#   'inflammation of the sinuses'],
#  ['this medicine', 'the inhaler', 'the sealed tray', '6', '30 .'],
#  ['incruse ellipta',
#   'umeclidinium bromide',
#   '55',
#   'umeclidinium',
#   '65',
#   'lactose monohydrate',
#   '2',
#   "lactose '",
#   'magnesium stearate',
#   'an inhalation powder',
#   'the ellipta inhaler',
#   'a grey plastic body'],
#  ['nucala',
#   'mepolizumab',
#   'a monoclonal antibody',
#   'a type of protein',
#   'severe asthma',
#   '6',
#   'many eosinophils',
#   'white blood cell',
#   'lungs',
#   'asthma attacks',
#   'medicines'],
#  ['nucala',
#   'allergic',
#   'mepolizumab',
#   'this medicine',
#   'worsening asthma',
#   '58',
#   'asthma - related side effects',
#   'your asthma',
#   'injection site reactions medicines',
#   'this type ( monoclonal antibodies',
#   'severe allergic reactions',
#   'side effects',
#   'asthma'],
#  ['the skin ( subcutaneous injection',
#   '12',
#   '100',
#   '1',
#   'the pre - filled pen',
#   'treatment',
#   'the treatment',
#   'your asthma symptoms',
#   'attacks'],
#  ['nucala',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'allergic reactions',
#   'allergic or allergic - like reactions',
#   '1',
#   '10',
#   'the injection',
#   'a drop in blood pressure )',
#   'swelling of eyelids',
#   'face , lips , tongue',
#   'mouth hives rash',
#   'immediately',
#   'a reaction',
#   'very common side effects',
#   'common side effects',
#   'swelling'],
#  ['nucala', '7'],
#  ['nucala',
#   'mepolizumab',
#   '1',
#   '100',
#   'sucrose',
#   'sodium phosphate dibasic heptahydrate',
#   'citric acid monohydrate',
#   'polysorbate 80',
#   'edta disodium dihydrate',
#   'injections',
#   'a pack',
#   'a multipack',
#   '3'],
#  ['ninlaro',
#   'a cancer medicine',
#   'ixazomib',
#   "a ' proteasome inhibitor",
#   'a cancer of the bone marrow',
#   'multiple myeloma',
#   'cell survival',
#   'a lot of proteins',
#   'proteasomes',
#   'other medicines',
#   'the plasma cell'],
#  ['ninlaro',
#   'allergic',
#   'ixazomib',
#   'this medicine',
#   'bleeding',
#   'persistent nausea',
#   'vomiting',
#   'diarrhoea'],
#  ['ninlaro',
#   'multiple myeloma',
#   'this medicine',
#   'lenalidomide',
#   'a medicine',
#   'dexamethasone',
#   'an anti - inflammatory medicine',
#   'once',
#   'first 3 weeks',
#   '3',
#   '4',
#   '25',
#   '2'],
#  ['all medicines',
#   'this medicine',
#   'side effects',
#   'very common serious side effects',
#   '1',
#   '10',
#   'low platelet counts',
#   'thrombocytopenia',
#   'nose bleeds',
#   'easily bruise nausea',
#   'vomiting',
#   'diarrhoea',
#   'numbness',
#   'tingling',
#   'burning of the hands or feet',
#   'peripheral neuropathy ) swelling of the legs or feet',
#   'peripheral oedema )',
#   'skin rash',
#   'itchy',
#   'rare side effects',
#   '1 , 000',
#   'severe skin rashes',
#   'red to purple bumps',
#   'rash',
#   'nausea',
#   'swelling',
#   'affect'],
#  ['this medicine',
#   'the blister',
#   'the capsule',
#   'any damage',
#   'medicine packaging'],
#  ['ninlaro',
#   '2 . 3',
#   'ixazomib',
#   'microcrystalline cellulose',
#   'magnesium stearate',
#   'talc',
#   'the capsule shell',
#   'gelatin , titanium dioxide',
#   'red iron oxide',
#   'shellac',
#   'propylene glycol',
#   'potassium hydroxide',
#   'black iron oxide',
#   '3',
#   '4 . 3',
#   '4'],
#  ['palforzia',
#   'allergic to peanuts',
#   'arachis hypogaea',
#   '4',
#   '17',
#   'treatment',
#   'peanut allergy',
#   'peanut ( desensitisation',
#   'allergic reactions',
#   'food allergies'],
#  ['palforzia',
#   'allergic',
#   'severe asthma',
#   'your asthma',
#   'a problem swallowing',
#   'long term problems',
#   'your digestive system',
#   'a severe mast cell disorder',
#   'severe or life - threatening anaphylaxis',
#   '60 days',
#   'the symptoms',
#   'asthma',
#   'this medicine'],
#  ['palforzia',
#   'this medicine',
#   'allergy',
#   'allergic reactions',
#   'anaphylaxis',
#   '3',
#   'treatment',
#   'allergic'],
#  ['palforzia',
#   'all medicines',
#   'this medicine',
#   'side effects',
#   'severe allergic reactions',
#   'the following symptoms',
#   'trouble breathing',
#   'throat tightness',
#   'trouble swallowing',
#   'speaking - changes in voice',
#   'dizziness',
#   'fainting',
#   'severe stomach cramps',
#   'pain',
#   'vomiting',
#   'diarrhoea',
#   'severe flushing',
#   'problems with the stomach and digestive system',
#   'stomach',
#   'symptoms',
#   'throat',
#   'allergic reactions',
#   'itching',
#   'skin',
#   'flushing',
#   'itching of the skin',
#   'breathing'],
#  ['this medicine', '25 .', 'any hard lumps of powder'],
#  ['palforzia',
#   '0 . 5',
#   '1',
#   '10',
#   '20',
#   'microcrystalline cellulose',
#   'colloidal anhydrous silica',
#   '100',
#   'oral powder in capsules',
#   'opening microcrystalline cellulose',
#   '300',
#   'magnesium stearate',
#   'beige oral powder',
#   '3',
#   '5',
#   '2',
#   '30'],
#  ['zerene',
#   'benzodiazepine',
#   'medicinal products',
#   'hypnotic actions',
#   'sleeping problems',
#   'treatment',
#   'problems sleeping'],
#  ['zerene',
#   'hypersensitivity',
#   'an allergy )',
#   'zaleplon',
#   'short periods',
#   'severe kidney or liver problems',
#   'myasthenia gravis',
#   'very weak',
#   'tired muscles',
#   'severe breathing',
#   'chest problems',
#   '18',
#   '8'],
#  ['zerene',
#   '10',
#   'difficulty falling asleep',
#   '65',
#   'mild to moderate liver problems',
#   '5',
#   'the capsule'],
#  ['zerene',
#   'all medicines',
#   'side effects',
#   'any other changes in your health',
#   'frequency',
#   '36',
#   '1',
#   '10',
#   '100',
#   '1 , 000',
#   '10 , 000'],
#  ['zerene',
#   'zaleplon',
#   '5',
#   'microcrystalline cellulose',
#   'pregelatinised starch',
#   'silicon dioxide',
#   'sodium lauryl sulphate',
#   'magnesium stearate',
#   'lactose monohydrate',
#   'indigo carmine',
#   'titanium dioxide',
#   'gelatin , titanium dioxide',
#   'red iron oxide',
#   'yellow iron oxide',
#   's - 13050 )',
#   '7']]

# %%
ENTITIES_NOT_INCLUDED
# Out:
# [['chronic hepatitis c infection',
#   '1865',
#   'the ns3 - 4a protease inhibitor',
#   'previously',
#   'an interferon - based regimen'],
#  ['their contraindications ( e . g . pregnancy precautions',
#   'the following medicines',
#   'alpha - 1 - adrenoreceptor antagonists',
#   'amiodarone',
#   'bepridil',
#   'quinidine',
#   'iii antiarrhythmics',
#   'certain heart disorders',
#   'irregular heart beat',
#   'heart',
#   'antiarrhythmics',
#   'astemizole',
#   'terfenadine',
#   'allergy symptoms',
#   'antihistamines',
#   'rifampicin',
#   'some infections',
#   'tuberculosis',
#   'antimycobacterial ) dihydroergotamine',
#   'ergonovine',
#   'ergotamine',
#   'methylergonovine',
#   'migraine',
#   'headaches',
#   'ergot derivatives',
#   'cisapride',
#   'some stomach conditions',
#   'gastrointestinal motility agents',
#   "st john ' s wort ( hypericum perforatum",
#   'an herbal product',
#   'anxiety',
#   'atorvastatin',
#   'lovastatin',
#   'simvastatin',
#   'lower cholesterol levels',
#   'hmg coa reductase inhibitors',
#   'pimozide',
#   'psychiatric conditions',
#   'neuroleptics )',
#   'sildenafil',
#   'tadalafil sildenafil',
#   'tadalafil',
#   'a heart and lung disorder',
#   'pulmonary arterial hypertension',
#   'quetiapine',
#   'schizophrenia',
#   'bipolar disorder',
#   'major depressive disorder',
#   'midazolam',
#   'mouth',
#   'triazolam',
#   'sedatives',
#   'hypnotics',
#   'carbamazepine',
#   'phenobarbital',
#   'phenytoin',
#   'epileptic seizures',
#   'anticonvulsants',
#   'another medicine',
#   'the package leaflets',
#   'your medicines',
#   'your hepatitis c virus',
#   'hcv',
#   'skin rash',
#   'a skin rash',
#   'itching',
#   'the rash',
#   'immediately',
#   'a rash',
#   'a 57 rash',
#   '57',
#   'rash',
#   '4',
#   'anaemia',
#   'your red blood cells',
#   'tiredness',
#   'weakness',
#   'shortness of breath',
#   'light - headedness',
#   'feeling of the heart racing',
#   'heart problems',
#   'heart failure',
#   'irregular heartbeat',
#   'slow heart rate',
#   'an abnormality',
#   'your heart tracing',
#   'ecg',
#   "' long qt syndrome '",
#   'a heart condition',
#   "' congenital qt syndrome",
#   'additional monitoring',
#   'your incivo treatment',
#   'liver problems',
#   'your liver',
#   'liver failure',
#   'signs',
#   'yellowing of the skin or eyes ( jaundice',
#   'swelling of the stomach ( ascites',
#   'legs',
#   'fluid',
#   'bleeding from swollen veins',
#   'varices',
#   'oesophagus',
#   'your liver disease',
#   'infections',
#   'an hepatitis b infection',
#   'organ transplant',
#   'liver',
#   'other organ transplant',
#   'blood tests',
#   'treatment',
#   'your treatment',
#   'much virus',
#   'your blood',
#   'the type of virus',
#   'these tests',
#   'your blood cells',
#   'chemistry',
#   'blood count levels',
#   'thyroid ( a gland in your neck',
#   'your metabolism ) levels',
#   'liver and kidney tests',
#   'kidney',
#   '65',
#   '18',
#   'other medicines',
#   'incivo incivo',
#   'any other medicines',
#   'the active substance )',
#   'the medicine flecainide',
#   'propafenone',
#   'irregular heart beat ( antiarrhythmics',
#   '58',
#   'alfentanil',
#   'fentanyl',
#   'pain ( analgesics )',
#   'surgery',
#   'sleep',
#   'digoxin',
#   'intravenous lidocaine',
#   'abnormal heart beat',
#   'clarithromycin',
#   'erythromycin',
#   'telithromycin',
#   'troleandomycin',
#   'bacterial infections ( antibacterials',
#   'warfarin',
#   'dabigatran',
#   'blood clots',
#   'anticoagulants',
#   'escitalopram',
#   'trazodone',
#   'mood disorders',
#   'antidepressants',
#   'metformin',
#   'diabetes ( antidiabetics',
#   'domperidone',
#   'vomiting',
#   'nausea',
#   'antiemetics',
#   'itraconazole',
#   'ketoconazole',
#   'posaconazole',
#   'voriconazole',
#   'fungal infections',
#   'antifungals',
#   'colchicine',
#   'inflammatory arthritis',
#   'anti - gout agents',
#   'rifabutin',
#   'certain infections',
#   'antimycobacterials )',
#   'alprazolam',
#   'benzodiazepines',
#   'zolpidem',
#   'non - benzodiazepine sedatives',
#   'amlodipine',
#   'diltiazem',
#   'felodipine',
#   'nicardipine',
#   'nifedipine',
#   'nisoldipine',
#   'verapamil',
#   'blood pressure',
#   'calcium channel blockers',
#   'maraviroc',
#   'hiv infections',
#   'ccr5 antagonist )',
#   'budesonide',
#   'inhaled',
#   'nasal fluticasone',
#   'dexamethasone',
#   'asthma',
#   'inflammatory and autoimmune conditions',
#   'corticosteroids )',
#   'bosentan',
#   'endothelin receptor antagonist',
#   'atazanavir / ritonavir',
#   'darunavir / ritonavir',
#   'fosamprenavir',
#   'ritonavir',
#   'lopinavir / ritonavir',
#   'hiv - protease inhibitors',
#   'abacavir',
#   'efavirenz',
#   'tenofovir disoproxil fumarate',
#   'zidovudine',
#   'reverse transcriptase inhibitors',
#   'fluvastatin',
#   'pitavastatin',
#   'pravastatin',
#   'rosuvastatin',
#   'lower cholesterol levels ( hmg coa reductase inhibitors',
#   'hormonal contraceptives',
#   "' the pill '",
#   'hormonal contraceptives oestrogen',
#   'based medicines',
#   'hormone replacement therapy',
#   'cyclosporine',
#   'sirolimus',
#   'tacrolimus',
#   'your immune system ( immunosuppressants',
#   'some rheumatic diseases',
#   'organ transplants salmeterol',
#   'inhaled beta agonists',
#   'repaglinide',
#   'type ii diabetes',
#   'blood glucose lowering medicine',
#   'methadone',
#   'opioid ( narcotic )',
#   'vardenafil',
#   'erectile dysfunction',
#   'pulmonary arterial hypertension ( pde - 5 inhibitors',
#   'body',
#   'pregnancy',
#   'pregnant',
#   '59 peginterferon alfa',
#   'all precautions',
#   'this therapy',
#   'any medicine',
#   'pregnancy precautions',
#   'special precautions',
#   'birth control',
#   'incivo therapy',
#   'the incivo treatment',
#   'the ribavirin package leaflet',
#   'continued contraception requirements',
#   'a hormonal contraceptive',
#   'birth control methods',
#   '2',
#   'fainting',
#   'problems with vision',
#   'incivo treatment',
#   'faint',
#   'problems with your vision',
#   'sodium this medicine',
#   '2 . 3',
#   'sodium',
#   'a controlled sodium diet',
#   'a low sodium diet'],
#  ['incivo',
#   'body',
#   '60',
#   'incivo treatment',
#   'peginterferon alfa',
#   'ribavirin',
#   'the package leaflets',
#   'these medicines',
#   '12',
#   'treatment',
#   '24 to 48',
#   'blood levels',
#   'your virus',
#   'weeks',
#   '4 and 12',
#   'a liver transplant',
#   '48',
#   'side effects',
#   'your treatment',
#   'the child resistant cap the plastic bottle',
#   'a child resistant cap',
#   'the plastic screw cap',
#   'the unscrewed cap',
#   'overdose',
#   'nausea',
#   'headache',
#   'diarrhoea',
#   'decreased appetite',
#   'abnormal taste',
#   'vomiting',
#   'immediately',
#   'a double dose',
#   '4',
#   'your medicine',
#   'the virus'],
#  ['swelling of lymph glands',
#   'painful skin blisters',
#   'blisters in the mouth , eyes , and / or genitals',
#   'your treatment',
#   'the following symptoms',
#   'weakness',
#   'shortness of breath',
#   'light - headedness',
#   'feeling of heart racing',
#   'anaemia',
#   'your red blood cells',
#   'fainting',
#   'painful inflammation of the joints',
#   'foot',
#   'gout',
#   'your eyesight',
#   'bleeding from the anus',
#   'frequency rate of the side effects',
#   'very common side effects',
#   '1',
#   '10',
#   'low red blood cell count',
#   'anaemia )',
#   'nausea',
#   'diarrhoea',
#   'vomiting',
#   'swollen veins in the rectum',
#   'anus ( haemorrhoids',
#   'pain in the anus or rectum',
#   'itching of the skin',
#   'common side effects',
#   'fungal infection in the mouth',
#   'low blood platelet count',
#   'decrease in lymphocytes',
#   'white blood cell )',
#   'decrease in thyroid gland activity',
#   'increase in uric acid in your blood',
#   'decrease in potassium in your blood',
#   'increase in bilirubin in your blood',
#   'change in taste',
#   'itching',
#   'anus',
#   'bleeding',
#   'rectum',
#   'a small tear in the skin',
#   'pain',
#   'bleeding during bowel movements',
#   'red',
#   'cracked',
#   'dry',
#   'scaly skin ( eczema )',
#   'scaly skin ( exfoliative rash',
#   'swelling of the arms and / or legs ( oedema',
#   'abnormal product taste',
#   'uncommon side effects',
#   '100',
#   'creatinine',
#   'your blood',
#   'gout )',
#   'damage to back of the eye',
#   'retina',
#   'inflammation of the anus and rectum',
#   'inflamed pancreas',
#   '62',
#   'severe rash',
#   'fatigue',
#   'increase of eosinophils',
#   'white blood cells',
#   'effects on liver , kidney or lung',
#   'hives',
#   'urticaria',
#   'dehydration',
#   'signs and symptoms',
#   'increased thirst',
#   'dry mouth',
#   'decreased urine frequency or volume',
#   'dark coloured urine',
#   'fluids',
#   'incivo combination treatment',
#   'rare side effects',
#   '1 , 000',
#   'a wide - spread severe rash',
#   'stevens - johnson syndrome',
#   'appendix',
#   'peginterferon alfa',
#   'ribavirin',
#   'these products'],
#  [],
#  ['silica colloidal anhydrous',
#   'the pack film',
#   'yellow caplet - shaped tablets',
#   '20',
#   '4'],
#  ['these symptoms',
#   'difficulty with walking , vision and balance',
#   'disappear',
#   'relapse',
#   'damaging your brain and spinal cord'],
#  ['depression',
#   'in the past',
#   'a serious infection',
#   'pneumonia',
#   'tuberculosis',
#   'tb',
#   'tb infections',
#   'treatment',
#   'liver problems zinbryta',
#   'serious liver problems',
#   'death',
#   'previous liver problems',
#   'blood tests',
#   'your liver function',
#   'a blood test',
#   'hepatitis b',
#   'your blood test',
#   'some liver problems',
#   'tests',
#   '6 months',
#   '4',
#   'these regular blood tests',
#   'your scheduled blood tests',
#   'any medical treatment',
#   'immediately',
#   'nausea',
#   'feeling sick',
#   'vomiting ( being sick )',
#   'stomach pain',
#   'increased tiredness loss of appetite',
#   'your skin',
#   'eyes',
#   '39',
#   'dark ( tea - coloured ) urine these symptoms',
#   'your liver',
#   '18',
#   '55',
#   'vaccinations',
#   'a vaccination',
#   'vaccines',
#   'seasonal flu vaccines',
#   'inactive vaccine',
#   "zinbryta ' s effect",
#   'other vaccines',
#   'live vaccines',
#   'pregnancy',
#   'pregnant',
#   'breast',
#   'machines zinbryta',
#   'your illness',
#   'a small amount of sodium',
#   '0 . 14',
#   'a sodium - restricted diet'],
#  ['yourself zinbryta',
#   'skin',
#   'thigh',
#   'stomach',
#   'back',
#   'arm',
#   'injecting zinbryta',
#   '7 .',
#   'the injections',
#   'your medicine',
#   'your treatment',
#   'side effects',
#   'serious extra side effects',
#   'zinbryta zinbryta',
#   'injection',
#   '2',
#   'injections'],
#  ['your treatment',
#   'immediately',
#   'a serious liver problem',
#   'these side effects',
#   'skin reactions',
#   'severe wide - spread rash',
#   'depression',
#   'sad',
#   'hopeless',
#   'yourself irritability',
#   'upset',
#   'easily nervousness',
#   'anxiety',
#   'thoughts of hurting',
#   'suicide lung infections',
#   'lung infection',
#   'pneumonia',
#   'bronchitis',
#   'low red blood cell counts',
#   'autoimmune haemolytic anaemia',
#   'paleness',
#   'dark urine shortness of breath',
#   'yellow increased tiredness',
#   'dark urine',
#   'skin or whites of the eyes turning yellow',
#   'symptoms',
#   'inflammation of the bowel ( colitis',
#   'diarrhoea',
#   'fever blood in your stools',
#   'white blood cells',
#   'lymphocytes',
#   'these white blood cells',
#   'a blood test',
#   'every 3 months',
#   '3',
#   'any serious side effects',
#   'other side effects',
#   'very common side effects',
#   'infections of the airways',
#   'coughs',
#   'colds',
#   'nasopharyngitis',
#   'upper respiratory tract infection',
#   'respiratory tract',
#   'liver enzymes',
#   'the blood',
#   'blood tests',
#   '42',
#   'common side effects',
#   'flu ( influenza )',
#   'sore throat',
#   'tonsillitis',
#   'pharyngitis',
#   'laryngitis',
#   'runny nose',
#   'rhinitis',
#   'skin rashes',
#   'inflamed , irritated',
#   'itchy',
#   'dry',
#   'peeling skin ( dermatitis',
#   'eczema',
#   'psoriasis )',
#   'skin infection',
#   'folliculitis',
#   'acne )',
#   'increases in body temperature ( fever ) inflamed',
#   'enlarged lymph nodes',
#   'lymphadenopathy',
#   'lymphadenitis',
#   'changes in your blood',
#   'weak uncommon side effects',
#   'immune disorder',
#   'affect the lungs',
#   'skin and lymph nodes',
#   'sarcoidosis',
#   'appendix v .'],
#  ['zinbryta syringes / pens',
#   '7',
#   'the syringe / pen',
#   'the solution',
#   'cloudy',
#   'slightly yellow'],
#  ['each pre - filled pen',
#   'the pack zinbryta',
#   'pre - filled pen',
#   'an attached needle'],
#  [],
#  ['sufficient treatment',
#   '25',
#   'insufficient treatment',
#   'copper excess )',
#   'excessive treatment',
#   'copper deficiency',
#   'pregnant',
#   'unusual muscle weakness',
#   'abnormal feeling in your limbs',
#   'other medicines',
#   'any other medicines',
#   'medicines',
#   'iron',
#   'calcium supplements',
#   'tetracyclines ( antibiotics',
#   'phosphorus',
#   'some medicines',
#   'tetracyclines',
#   'fluoroquinolones',
#   'antibiotics',
#   'stomach',
#   'some dairy products',
#   'zinc salts',
#   'stomach upset',
#   'side effect',
#   'a small amount of protein - containing food',
#   'pregnancy',
#   'anti - copper therapy',
#   'wilzin therapy',
#   '50',
#   'allergic reactions'],
#  ['1 to 6',
#   '6',
#   '16',
#   '57',
#   'stomach',
#   '4',
#   'another anti - copper agent',
#   'penicillamine',
#   'the two medicines',
#   'swallow capsules',
#   'open the capsule',
#   'mix the powder',
#   'nausea',
#   'vomiting',
#   'dizziness',
#   'a double dose'],
#  ['wilzin intake',
#   'gastric irritation',
#   'treatment',
#   'changes in blood tests',
#   'an increase in some liver and pancreatic enzymes',
#   'a decrease in blood red and white cells',
#   'appendix v .',
#   'this medicine'],
#  ['wilzin'],
#  ['the printing ink',
#   'black iron oxide',
#   'shellac',
#   '250',
#   'a polyethylene bottle',
#   'a polypropylene and polyethylene closure',
#   'a cotton filler'],
#  ['biktarvy',
#   'a nucleotide reverse transcriptase inhibitor ( ntrti ) biktarvy',
#   'your immune system',
#   'developing illnesses',
#   'hiv infection'],
#  ['the following medicines',
#   "tuberculosis - st . john ' s wort",
#   'hypericum perforatum',
#   'a herbal remedy',
#   'depression',
#   'anxiety',
#   'liver problems',
#   'liver disease',
#   'hepatitis',
#   'chronic hepatitis b',
#   'c',
#   'antiretrovirals',
#   'severe and potentially fatal liver complications',
#   'hepatitis b infection',
#   'the best treatment regimen',
#   '3',
#   'inflammation',
#   'infection joint pain',
#   'stiffness',
#   'bone problems',
#   'these symptoms',
#   '4',
#   'side effects',
#   'kidney problems',
#   'pass on hiv',
#   'effective antiretroviral therapy',
#   'the precautions',
#   'infecting',
#   'hiv infection',
#   'other illnesses',
#   '18',
#   'other medicines',
#   'any other medicines',
#   'your blood',
#   'your medicines',
#   'your blood levels',
#   'tuberculosis st',
#   "john ' s wort",
#   'these medicines',
#   'hiv',
#   'hepatitis b',
#   'adefovir dipivoxil',
#   'atazanavir',
#   'lamivudine',
#   'tenofovir disoproxil antibiotics',
#   'azithromycin',
#   'clarithromycin',
#   'rifabutin',
#   'rifapentine anticonvulsants',
#   'epilepsy',
#   'carbamazepine',
#   'oxcarbazepine',
#   'phenobarbital',
#   'phenytoin immunosuppressants',
#   'a transplant',
#   'ciclosporin ulcer',
#   'healing medicines',
#   'sucralfate',
#   'your treatment',
#   'antacids',
#   'stomach ulcers',
#   'heartburn',
#   'acid reflux',
#   'aluminium',
#   'magnesium hydroxide mineral supplements',
#   'vitamins',
#   'magnesium',
#   'iron',
#   'magnesium supplements',
#   '2',
#   'supplements',
#   'iron supplements',
#   'pregnancy',
#   'pregnant',
#   'immediately',
#   'your antiretroviral therapy',
#   'regular blood tests',
#   'diagnostic tests',
#   'nucleoside reverse transcriptase inhibitors',
#   'nrtis',
#   'the protection',
#   'breast',
#   'passing the virus',
#   'machines biktarvy',
#   'dizziness',
#   'dizzy',
#   'sodium this medicine',
#   '1 mmol sodium'],
#  ['dialysis',
#   'side effects',
#   '4',
#   'emergency department',
#   '18',
#   'vomit',
#   '1',
#   'biktarvy tablets',
#   'virus',
#   'the medicine',
#   'the disease',
#   'both hiv infection',
#   'hepatitis b',
#   'your biktarvy treatment',
#   'blood tests',
#   'several months',
#   'treatment',
#   'advanced liver disease',
#   'cirrhosis',
#   'your hepatitis',
#   'unusual symptoms',
#   'symptoms',
#   'hepatitis b infection'],
#  ['biktarvy',
#   'many months',
#   'any symptoms',
#   'other symptoms',
#   'muscle weakness',
#   'weakness',
#   'hands',
#   'feet',
#   'trunk',
#   'body',
#   'palpitations',
#   'tremor',
#   'hyperactivity',
#   'common side effects',
#   'affect',
#   '1',
#   '10',
#   'depression abnormal dreams',
#   'headache',
#   'dizziness',
#   'diarrhoea',
#   'sick ( nausea ) tiredness ( fatigue )',
#   'uncommon side effects',
#   '100',
#   'anaemia vomiting',
#   'stomach pain',
#   'problems with digestion',
#   'discomfort after meals ( dyspepsia )',
#   'wind ( flatulence ) swelling of the face , lips , tongue',
#   'throat ( angioedema )',
#   'itching ( pruritus )',
#   'rash hives ( urticaria )',
#   'joint pain',
#   'arthralgia )',
#   'suicidal behaviour anxiety sleep disorders',
#   '37',
#   'rare side effects',
#   '1000',
#   'stevens - johnson syndrome',
#   'sjs',
#   'a serious life - threatening condition',
#   'flu - like symptoms',
#   'few days',
#   'painful red or purple skin',
#   'blisters',
#   'skin',
#   'mouth , nose , and genitals',
#   'red',
#   'painful , watery eyes',
#   'blood tests',
#   'higher levels of substances',
#   'bilirubin',
#   'serum creatinine',
#   'the blood',
#   'bone problems',
#   'combination antiretroviral medicines',
#   'a bone disease',
#   'osteonecrosis',
#   'death',
#   'bone tissue',
#   'loss of blood supply to the bone',
#   'corticosteroids',
#   'a very weak immune system',
#   'overweight',
#   'this disease',
#   'joint stiffness',
#   'joint aches',
#   'pains',
#   'hip',
#   'knee',
#   'shoulder',
#   'difficulty with movement',
#   'hiv therapy',
#   'an increase in weight',
#   'blood lipids',
#   'glucose',
#   'appendix v .'],
#  ['biktarvy'],
#  ['each biktarvy tablet',
#   'bictegravir sodium equivalent',
#   'tenofovir alafenamide fumarate equivalent',
#   'coating polyvinyl alcohol , titanium dioxide',
#   'macrogol',
#   'talc',
#   'iron oxide',
#   'iron oxide black',
#   'the pack biktarvy film',
#   'purplish',
#   'film - coated tablets',
#   '30',
#   '3',
#   'a silica gel desiccant',
#   'the silica gel desiccant'],
#  ['the blood sugar', 'complications', 'your diabetes'],
#  ['kidney problems',
#   'major surgery',
#   'recently',
#   'a severe illness',
#   'infection',
#   'diabetic control',
#   '18',
#   '75',
#   'a hypo ( low blood sugar',
#   'a hypo ( short for hypoglycaemia',
#   'blood sugar gets too low',
#   'other medicines',
#   'liver or kidney problems',
#   '2 .',
#   'a hypo',
#   'cold sweat',
#   'cool pale skin',
#   'headache',
#   'rapid heart beat',
#   'heart',
#   'feeling sick',
#   'feeling very hungry',
#   'temporary changes in vision',
#   'drowsiness',
#   'unusual tiredness',
#   'weakness',
#   'nervousness',
#   'tremor',
#   'feeling anxious',
#   'feeling confused',
#   'difficulty in concentrating',
#   'blood sugar is low',
#   'glucose tablets',
#   'symptoms',
#   'hypoglycaemia',
#   'blood sugar levels',
#   'novonorm treatment',
#   'unconscious',
#   'severe hypoglycaemia',
#   'brain damage ( temporary or permanent ) and even death',
#   'blood sugar gets too high your blood sugar',
#   'hyperglycaemia',
#   'an infection',
#   'a fever',
#   'too high blood sugar',
#   'increased urination',
#   'feeling thirsty',
#   'dry skin',
#   'dry mouth',
#   '48',
#   'any other medicines',
#   'metformin',
#   'monoamine oxidase inhibitors',
#   'maoi )',
#   'depression',
#   'beta blockers',
#   'high blood pressure',
#   'heart conditions',
#   'ace - inhibitors',
#   'salicylates ( e . g . aspirin )',
#   'octreotide',
#   'cancer )',
#   'nonsteroidal anti - inflammatory drugs',
#   'nsaid )',
#   'a type of painkillers )',
#   'steroids ( anabolic steroids',
#   'corticosteroids',
#   'anemia',
#   'inflammation',
#   'oral contraceptives ( birth control pills',
#   'thiazides ( diuretics',
#   "' water pills",
#   'danazol',
#   'breast cysts',
#   'endometriosis',
#   'thyroid products',
#   'low levels of thyroid hormones',
#   'thyroid',
#   'sympathomimetics',
#   'asthma',
#   'clarithromycin',
#   'trimethoprim',
#   'rifampicin ( antibiotic medicines',
#   'itraconazole',
#   'ketokonazole ( antifungal medicines',
#   'high blood fats',
#   'ciclosporin',
#   'the immune system',
#   'deferasirox',
#   'chronic iron overload',
#   'clopidogrel',
#   'blood clots',
#   'phenytoin',
#   'carbamazepine',
#   'phenobarbital',
#   'epilepsy',
#   "john ' s wort",
#   'herbal medicine',
#   'the blood sugar',
#   'pregnancy',
#   'pregnant',
#   'this medicine',
#   'a machine',
#   'blood sugar is low or high',
#   'frequent hypos',
#   'warning signs of hypos'],
#  ['4', '16', 'your blood sugar', 'a hypo', 'your diabetes', 'your treatment'],
#  ['side effect',
#   'hypoglycaemic reactions',
#   'hypoglycaemic unconsciousness',
#   'stomach pain',
#   'diarrhoea',
#   '1 , 000',
#   'acute coronary syndrome',
#   'vomiting constipation',
#   'visual disturbances severe liver problems',
#   'abnormal liver function',
#   'liver',
#   'increased liver enzymes',
#   'your blood',
#   'known hypersensitivity',
#   'rash',
#   'itchy skin',
#   'redening of the skin',
#   'swelling of the skin',
#   'feeling sick',
#   'nausea',
#   'appendix'],
#  ['1',
#   'the pack novonorm tablets',
#   '0 . 5',
#   'four blister pack sizes',
#   '30',
#   '90',
#   '120',
#   '270'],
#  [],
#  ['33',
#   'any allergic reaction',
#   'a serious infection',
#   'a high temperature',
#   '38 .',
#   'your vaccination',
#   'feeling better',
#   'a minor infection',
#   'cold',
#   'your immune system',
#   'a blood test',
#   'infection',
#   'certain viruses',
#   'vaccination',
#   'these tests',
#   'recently',
#   'a bleeding problem',
#   'bruise easily',
#   'the vaccination',
#   'fainting',
#   'any needle injection',
#   'fainted',
#   'a previous injection',
#   'side effects',
#   'temperature',
#   'monitoring of temperature',
#   'paracetamol',
#   'other medicines',
#   'lower fever',
#   'any other vaccine',
#   'any treatments',
#   'corticosteroid treatments',
#   'chemotherapy',
#   'cancer',
#   'immune system',
#   'some other vaccines',
#   'the other vaccine',
#   'arm',
#   'any side effects',
#   'pregnancy',
#   'pregnant',
#   '4',
#   'thiomersal pumarix',
#   'any known allergies',
#   'potassium pumarix',
#   '1 mmol sodium',
#   '1',
#   'potassium'],
#  [],
#  ['a hard lump',
#   'itching',
#   'warmth swollen glands',
#   'your neck',
#   'dizzy',
#   'feeling unwell',
#   'unusual weakness',
#   '35',
#   'stomach pain',
#   'acid indigestion',
#   'sleep tingling',
#   'numbness of the hands',
#   'feet shortness of breath pain',
#   'the chest itching',
#   'rash pain in the back or neck',
#   'stiff muscles',
#   'muscle spasms',
#   'pain in your leg',
#   'hand',
#   '0 . 5',
#   'a similar vaccine',
#   '6 - 9',
#   '3 - 5',
#   'some side effects',
#   '6',
#   '17',
#   '05 / 2005',
#   'injection site pain',
#   'the side effects',
#   'h1n1 as03',
#   'vaccines',
#   'immediately',
#   'a dangerously low blood pressure',
#   'generalised skin reactions',
#   'urticaria',
#   'hives',
#   'vaccination',
#   'flu',
#   '1 , 000',
#   'serious stabbing',
#   'throbbing pain',
#   'your nerves low blood platelet count',
#   'bleeding',
#   '10 , 000',
#   'inflammation',
#   'your blood vessels',
#   'vasculitis',
#   'skin rashes',
#   'kidney problems problems',
#   'your brain and nerves',
#   'inflammation of the central nervous system',
#   'encephalomyelitis',
#   'inflammation of nerves ( neuritis',
#   'paralysis',
#   'guillain - barré syndrome'],
#  ['pumarix'],
#  ['5 / 2005',
#   'potassium chloride',
#   'the pack the suspension',
#   'white opalescent suspension',
#   'a whitish homogeneous liquid',
#   'the mixed vaccine',
#   'a whitish emulsion',
#   '50',
#   '2 . 5',
#   '25',
#   'emulsion'],
#  ['somakit toc',
#   'gallium ( 68ga ) edotreotide',
#   'the procedure',
#   'the radiopharmaceutical',
#   'radiation'],
#  ['somakit toc',
#   'others medical conditions',
#   'body',
#   'cushing syndrome',
#   'inflammation',
#   'thyroid disease',
#   'tumour ( of pituitary gland , lung , brain , breast , immune system',
#   'thyroid , adrenal gland',
#   'disease of spleen',
#   'the images',
#   'other medicines',
#   'somatostatin analogues',
#   'glucocorticoids',
#   'pregnant',
#   'special precaution',
#   'the procedure',
#   'any other medicines',
#   'corticosteroids',
#   'your treatment',
#   'pregnancy',
#   'the medical procedure',
#   'the administration of somakit toc',
#   'breast - feeding',
#   'machines',
#   'sodium this medicine',
#   '1 . 5',
#   '32 . 5',
#   'sodium',
#   'a controlled sodium diet'],
#  ['somakit toc',
#   'radiolabelling , somakit toc',
#   'intravenous injection',
#   'a single injection',
#   'injection',
#   'the test',
#   'pregnant',
#   '8 hours',
#   'the injection',
#   'any special precautions',
#   'this medicine',
#   'overdose',
#   'an overdose',
#   'the appropriate treatment',
#   'bladder'],
#  ['somakit toc', 'appendix v .'],
#  ['somakit toc', 'deterioration'],
#  ['somakit toc',
#   'a glass vial',
#   'black flip - off',
#   'a white powder',
#   'yellow flip',
#   'cap',
#   'a clear and colourless solution',
#   'the radioactive substance'],
#  ['afinitor',
#   'the tumour',
#   'a steroidal aromatase inhibitor',
#   'the tumours',
#   'advanced kidney cancer',
#   'advanced renal cell carcinoma',
#   'vegf - targeted therapy',
#   'your disease'],
#  ['temsirolimus',
#   'a different dose of afinitor',
#   'diabetes',
#   'high level of sugar in your blood',
#   'blood sugar levels',
#   'worsen diabetes mellitus',
#   'insulin',
#   'oral antidiabetic agent therapy',
#   'excessive thirst',
#   'increased frequency of urination',
#   'a vaccine',
#   'high cholesterol',
#   'cholesterol',
#   'other blood fats',
#   'recent major surgery',
#   'an unhealed wound',
#   'surgery',
#   'wound healing',
#   'an infection',
#   'your infection',
#   'previously',
#   'hepatitis b',
#   '4',
#   'side effects',
#   'immune system',
#   'fever',
#   'some infections',
#   'fatal consequences',
#   'your kidney function',
#   'shortness of breath',
#   'cough',
#   'mouth ulcers',
#   'sores',
#   'your treatment',
#   'a mouthwash , gel',
#   'other products',
#   'ulcers',
#   'these symptoms',
#   'regular blood tests',
#   'blood cells',
#   'white blood cells',
#   'red blood cells',
#   'platelets',
#   'an unwanted effect on these cells',
#   'blood tests',
#   'level of creatinine',
#   'liver function',
#   'transaminases',
#   'your blood sugar',
#   'cholesterol levels',
#   '18',
#   'other medicines',
#   'the other medicines',
#   'any other medicines',
#   'ketoconazole',
#   'itraconazole',
#   'voriconazole',
#   'fluconazole',
#   'other antifungals',
#   'fungal infections',
#   'clarithromycin',
#   'telithromycin',
#   'erythromycin',
#   'antibiotics',
#   'bacterial infections',
#   'ritonavir',
#   'hiv infection',
#   'aids',
#   'verapamil',
#   'diltiazem',
#   'heart conditions',
#   'high blood pressure',
#   'dronedarone',
#   'a medicine',
#   'heart beat',
#   'ciclosporin',
#   'rejecting organ transplants',
#   'imatinib',
#   'abnormal cells',
#   'converting enzyme ( ace ) inhibitors',
#   'ramipril',
#   'other cardiovascular problems',
#   'nefazodone',
#   'depression',
#   'rifampicin',
#   'tuberculosis',
#   'tb',
#   'efavirenz',
#   'nevirapine',
#   "john ' s wort",
#   'hypericum perforatum',
#   'a herbal product',
#   'other conditions',
#   'dexamethasone',
#   'a corticosteroid',
#   'a wide variety of conditions',
#   'inflammatory or immune problems',
#   'phenytoin',
#   'carbamazepine',
#   'phenobarbital',
#   'other anti - epileptics',
#   'seizures',
#   'these medicines',
#   'a different medicine',
#   'pregnancy',
#   'fertility pregnancy',
#   'pregnant',
#   'contraception',
#   '8',
#   '2',
#   'menstrual periods ( amenorrhoea',
#   'unusually tired',
#   'fatigue',
#   'lactose afinitor',
#   'lactose ( milk sugar',
#   'intolerance to some sugars'],
#  ['a lower dose of afinitor',
#   'urgent treatment',
#   'a double dose',
#   'the forgotten tablets'],
#  ['pneumonitis',
#   '46',
#   'excessive thirst',
#   'high urine output',
#   'increased appetite',
#   'weight loss',
#   'tiredness',
#   'diabetes )',
#   'bleeding ( haemorrhage',
#   'gut wall',
#   'severely decreased urine output',
#   'kidney failure',
#   '100',
#   'skin rash',
#   'joint pain',
#   'loss of appetite',
#   'nausea',
#   'jaundice',
#   'yellowing of the skin',
#   'pain in the upper right abdomen',
#   'pale stools',
#   'dark urine',
#   'hepatitis b reactivation )',
#   'breathlessness',
#   'swelling of the feet or legs',
#   'heart failure )',
#   'pain in one of the legs',
#   'calf',
#   'redness',
#   'warm skin in the affected area',
#   'a blood vessel ( vein ) in the legs',
#   'blood clotting',
#   'shortness of breath',
#   'chest pain',
#   'coughing up blood',
#   'pulmonary embolism',
#   'a condition',
#   'arteries',
#   'lungs',
#   'swelling in the legs',
#   'feeling confused',
#   'pain in the back',
#   'sudden kidney failure )',
#   'hives',
#   'dizziness',
#   'serious allergic reaction',
#   'hypersensitivity )',
#   '1 , 000',
#   'rapid breath',
#   'acute respiratory distress syndrome',
#   'these side effects',
#   'high level of sugar in the blood ( hyperglycaemia',
#   'loss of appetite disturbed taste ( dysgeusia )',
#   'headache nose bleeds',
#   'epistaxis )',
#   'cough mouth ulcers upset stomach',
#   'feeling sick ( nausea )',
#   'diarrhoea skin rash itching ( pruritus )',
#   'feeling weak',
#   'tired tiredness',
#   'pale skin',
#   'signs of low level of red blood cells',
#   'anaemia ) swelling of arms , hands , feet , ankles',
#   'body',
#   'oedema',
#   'high level of lipids',
#   'the blood ( hypercholesterolaemia )',
#   '47',
#   'spontaneous bleeding',
#   'bruising',
#   'low level of platelets',
#   'thrombocytopenia )',
#   'breathlessness ( dyspnoea )',
#   'thirst',
#   'low urine output',
#   'dry flushed skin',
#   'irritability',
#   'dehydration )',
#   'trouble sleeping ( insomnia )',
#   'headache',
#   'high blood pressure',
#   'hypertension )',
#   'sore throat',
#   'mouth ulcers',
#   'infections',
#   'low level of white blood cells',
#   'leukopenia',
#   'lymphopenia',
#   'neutropenia',
#   'fever inflammation',
#   'lining of the mouth',
#   'stomach',
#   'gut dry mouth heartburn',
#   'dyspepsia',
#   'sick ( vomiting )',
#   'difficulty in swallowing ( dysphagia )',
#   'abdominal pain',
#   'acne rash',
#   'pain',
#   'palms',
#   'hands',
#   'soles',
#   'feet',
#   'hand - foot syndrome',
#   'reddening of the skin',
#   'erythema )',
#   'joint pain pain',
#   'the mouth menstruation disorders',
#   'irregular periods',
#   'the blood ( hyperlipidaemia',
#   'raised triglycerides )',
#   'low level of potassium in the blood ( hypokalaemia',
#   'low level of phosphate in the blood ( hypophosphataemia )',
#   'low level of calcium in the blood ( hypocalcaemia )',
#   'dry skin',
#   'skin exfoliation',
#   'skin lesions',
#   'nail disorders',
#   'loss of hair abnormal results of liver blood',
#   'liver',
#   'alanine and aspartate aminotransferase )',
#   'abnormal results',
#   'renal blood tests',
#   'increased creatinine )',
#   'swelling of the eyelid protein in the urine',
#   'weakness',
#   'frequent infections',
#   'low level of blood cells',
#   'pancytopenia',
#   'loss of sense of taste ( ageusia )',
#   'coughing up blood ( haemoptysis )',
#   'menstruation disorders',
#   'periods ( amenorrhoea )',
#   'passing urine',
#   'daytime chest pain',
#   'abnormal wound healing',
#   'hot flushes discharge',
#   'eye',
#   'pink eye',
#   'red eye',
#   'conjunctivitis',
#   'low level of red blood cells',
#   'a type of anaemia',
#   'pure red cell aplasia',
#   'eyes',
#   'mouth',
#   'the tongue',
#   'angioedema',
#   '48',
#   'the side effects',
#   'mild to moderate',
#   'your treatment',
#   'appendix v .'],
#  ['afinitor', 'these measures'],
#  ['10',
#   'butylhydroxytoluene',
#   'magnesium stearate',
#   'lactose monohydrate',
#   'the pack afinitor',
#   'white to slightly yellowish , elongated tablets',
#   'blister packs',
#   '30',
#   '90'],
#  ['what laventair ellipta',
#   'your breathing difficulties',
#   'a sudden attack of breathlessness',
#   'wheezing',
#   'attack',
#   'a quick - acting reliever inhaler',
#   'salbutamol )'],
#  ['an enlarged prostate',
#   'difficulty passing urine',
#   'a blockage in your bladder',
#   'epilepsy',
#   'thyroid gland problems',
#   'diabetes',
#   'severe liver problems',
#   'immediate breathing difficulties',
#   'tightness of the chest',
#   'coughing',
#   'wheezing',
#   'breathlessness',
#   'immediately',
#   'your laventair ellipta inhaler',
#   'a serious condition',
#   'paradoxical bronchospasm',
#   'eye problems',
#   'eye pain',
#   'discomfort',
#   'temporary blurring of vision',
#   'visual halos',
#   'coloured images',
#   'red eyes',
#   'an acute attack of narrow - angle glaucoma',
#   '18',
#   'other medicines',
#   'any other medicines',
#   'some medicines',
#   'side effects',
#   'medicines',
#   'beta blockers',
#   'propranolol',
#   'other heart problems',
#   'ketoconazole',
#   'itraconazole',
#   'fungal infections',
#   'clarithromycin',
#   'telithromycin',
#   'bacterial infections',
#   'ritonavir',
#   'hiv infection',
#   'potassium in your blood',
#   'some diuretics ( water tablets )',
#   'methylxanthine',
#   'steroids',
#   'other long - acting medicines',
#   'breathing problems',
#   'tiotropium',
#   'indacaterol',
#   'these medicines',
#   'pregnancy',
#   'pregnant',
#   'breast',
#   'machines',
#   'intolerance to some sugars'],
#  ['a quick - acting reliever inhaler',
#   'salbutamol )',
#   'the inhaler',
#   'lungs',
#   'mouth',
#   'the ellipta inhaler',
#   'your symptoms',
#   'your copd symptoms',
#   'cough',
#   'your quick - acting inhaler',
#   'heart is beating faster than usual',
#   'feel shaky',
#   'visual disturbances',
#   'a dry mouth',
#   'a headache',
#   'wheezy',
#   'breathless',
#   'your quick - acting reliever inhaler',
#   'feel better'],
#  ['tightness of the chest',
#   'wheezing',
#   'breathlessness',
#   'a serious condition',
#   'paradoxical bronchospasm',
#   'common side effects',
#   'painful and frequent urination',
#   'a urinary tract infection',
#   'sore throat',
#   'runny nose',
#   'feeling of pressure',
#   'pain in the cheeks and forehead',
#   'inflammation of the sinuses',
#   'sinusitis',
#   'headache',
#   'cough pain',
#   'irritation in the back of the mouth',
#   'throat constipation',
#   'dry mouth infection of the upper airways',
#   'irregular heart beat faster heart beat awareness of heart beat ( palpitations )',
#   'rash tremor taste disturbance hoarseness',
#   'blurred vision',
#   'the measured eye pressure decrease in vision',
#   'pain in your eyes',
#   'high pressure',
#   'glaucoma',
#   'difficulty and pain',
#   'passing urine',
#   'a bladder obstruction',
#   'urinary retention',
#   'frequency',
#   'dizziness',
#   'appendix'],
#  ['what laventair ellipta',
#   "' laventair ellipta",
#   'the pack laventair ellipta',
#   'an inhalation powder',
#   'the ellipta inhaler',
#   'a light grey plastic body',
#   'a red mouthpiece cover',
#   'a dose counter',
#   'a foil laminate tray',
#   'a peelable foil lid',
#   'a desiccant packet',
#   'the packaging',
#   'a white powder',
#   'each inhaler',
#   '7',
#   '30',
#   'multipacks',
#   '90'],
#  ['moderate to severe " plaque psoriasis',
#   'reduce symptoms',
#   'scaling',
#   'shedding',
#   'flaking',
#   'itching',
#   'pain',
#   'burning'],
#  ['a vaccination during treatment',
#   'serious side effects',
#   'these conditions',
#   'any signs',
#   'serious allergic reaction',
#   'fever',
#   'flu like symptoms',
#   'muscle aches',
#   'cough',
#   'shortness of breath',
#   'burning when you urinate',
#   'urinating more often than usual',
#   'blood in your phlegm',
#   'weight loss',
#   'diarrhoea',
#   'stomach pain',
#   'warm',
#   'red',
#   'painful skin',
#   'sores on your body',
#   'your psoriasis',
#   'serious allergic reactions',
#   'hives',
#   'side effects',
#   '18',
#   'other medicines',
#   'any other medicines',
#   'recently',
#   'a vaccination',
#   'vaccines ( live vaccines',
#   'pregnancy',
#   'breast - feeding tremfya',
#   'pregnant',
#   'adequate contraception',
#   'least',
#   '12 weeks',
#   'the last tremfya dose',
#   'machines tremfya'],
#  ['treatment', 'symptoms', 'psoriasis'],
#  ['tremfya',
#   'headache',
#   'joint pain',
#   'arthralgia',
#   'diarrhoea',
#   'stomach flu ( gastroenteritis )',
#   'redness at the injection site',
#   'hives',
#   'fungal infection of the skin',
#   'toes',
#   "athlete ' s foot",
#   'herpes simplex infections',
#   '100',
#   'pain at the injection site',
#   'skin rash',
#   '38',
#   'appendix v .'],
#  ['tremfya', 'the refrigerator'],
#  ['single - dose pre - filled syringes'],
#  ['persistent or recurrent cteph',
#   'heart',
#   'lungs',
#   'shortness of breath',
#   'dizziness',
#   'tiredness',
#   'fainting',
#   'palpitations',
#   'abnormal heartbeat',
#   'dry cough',
#   'chest pain',
#   'swollen ankles or legs',
#   'pulmonary artery',
#   'blood flow',
#   'improved blood flow',
#   'oxygen',
#   'body',
#   'reduced strain on the heart',
#   'the symptoms'],
#  ['a higher pressure in the blood vessels between the heart and the lungs',
#   'severe changes in heart rate severe coronary heart disease',
#   'unstable angina a heart defect',
#   'a faulty heart valve',
#   'any disease of the heart',
#   'bleeding',
#   'example active stomach ulcers',
#   'injuries',
#   'other bleeding conditions',
#   'a stroke',
#   'last 3 months',
#   '3',
#   'brain',
#   'any liver disease',
#   'kidney disease',
#   'medically obese',
#   'bmi',
#   '30',
#   'a low sodium diet',
#   'your treatment',
#   'blood pressure decreases',
#   'hypotension',
#   'a rapid increase in breathing difficulties',
#   'persistent cough',
#   'congestion in the lungs',
#   'asthma',
#   'excessive bleeding',
#   'your blood from clotting children',
#   'other medicines',
#   'any other medicines',
#   'medicines',
#   'high blood pressure ( antihypertensive medicines',
#   'other vasodilators',
#   'urination ( diuretics',
#   'furosemide - medicines',
#   'blood clotting ( anticoagulants',
#   'warfarin',
#   'heparin',
#   'nitric oxide based products',
#   'any non - steroidal anti - inflammatory ( nsaid ) medicines',
#   'acetylsalicylic acid',
#   'ibuprofen',
#   'gemfibrozil',
#   'rifampicin',
#   'trimethoprim',
#   'deferasirox',
#   'phenytoin',
#   'carbamazepine',
#   'phenobarbital',
#   "st . john ' s wort",
#   'the dosage of trepulmix',
#   'pregnancy',
#   'pregnant',
#   'contraception',
#   'trepulmix treatment',
#   'breast',
#   'machines trepulmix',
#   'low blood pressure',
#   'dizziness',
#   'fainting',
#   'a controlled sodium diet',
#   '1',
#   'infusion this medicine',
#   '36 . 8',
#   'sodium',
#   'cooking / table salt )',
#   '1 . 8',
#   '2 . 5',
#   '37 . 3',
#   '1 . 9',
#   '5',
#   '39 . 1',
#   '2 . 0',
#   '10',
#   '37 . 4'],
#  ['10',
#   'the infusion rate',
#   'your condition',
#   'special dose adjustments',
#   'liver or kidney disease',
#   'kidney',
#   'infusion rate the infusion rate',
#   'an effective maintenance rate',
#   'symptoms',
#   'cteph',
#   'undesirable effects',
#   'your symptoms',
#   'discomfort',
#   'your disease',
#   'another treatment',
#   'overdose trepulmix',
#   'nausea',
#   'vomiting',
#   'diarrhoea',
#   'low blood pressure',
#   'dizziness',
#   'light - headedness',
#   'fainting',
#   'skin flushes',
#   'headaches',
#   'trepulmix solution',
#   'abrupt withdrawal',
#   'sudden reductions',
#   'the pulmonary arterial hypertension',
#   'rapid and severe deterioration in your condition'],
#  ['trepulmix',
#   'the infusion site bleeding',
#   'swollen eyelids',
#   'eyelid oedema )',
#   'indigestions',
#   'vomiting',
#   'skin itches',
#   'exanthema',
#   'back pain',
#   'decreased appetite',
#   'tiredness',
#   'pulmonary arterial hypertension',
#   'pah',
#   'bleeding episodes',
#   'nose bleeds',
#   'coughing up blood',
#   'blood in the urine',
#   'bleeding from the gums',
#   'blood in the faeces',
#   'infection',
#   'the infusion site abscess',
#   'blood clotting cells',
#   'platelets',
#   'the blood ( thrombocytopenia )',
#   'bone pain',
#   'discolouration',
#   'raised bumps tissue infection under the skin ( cellulitis',
#   'appendix'],
#  ['a trepulmix vial',
#   'a single reservoir ( syringe ) of undiluted trepulmix',
#   'damage',
#   'discolouration',
#   'other signs of deterioration'],
#  ['treprostinil ( as sodium salt )',
#   '50',
#   '100',
#   'sodium citrate',
#   'sodium chloride',
#   'sodium hydroxide',
#   'metacresol',
#   'slightly yellow solution',
#   'a rubber stopper',
#   'infusion trepulmix',
#   'a yellow rubber cap',
#   'a blue rubber cap',
#   'a green rubber cap',
#   'a red rubber cap'],
#  ['stopping blood clots',
#   'a heart attack',
#   'your dialysis machine',
#   'severe kidney problems'],
#  ['your clotting cells',
#   'platelets',
#   'this reaction',
#   'heparin - induced thrombocytopenia',
#   'last 100 days',
#   '100',
#   'antibodies',
#   'your blood',
#   'bleeding',
#   'a condition',
#   'stomach ulcer',
#   'recent surgery',
#   'brain',
#   'eyes',
#   'recent bleeding stroke',
#   'blood clots in your body',
#   'spinal or epidural anaesthesia',
#   'lumbar puncture',
#   'within 24 hours',
#   '24',
#   'precautions thorinane',
#   'other medicines',
#   'your platelets',
#   'spinal or epidural anesthesia',
#   'operations',
#   'anaesthetics',
#   'this procedure',
#   'a heart valve',
#   'endocarditis',
#   'an infection',
#   'lining of the heart',
#   'gastric ulcer',
#   'a recent stroke',
#   'high blood pressure',
#   'diabetes',
#   'blood vessels in the eye',
#   'diabetic retinopathy',
#   'an operation',
#   'recently',
#   '65',
#   '75',
#   'kidney problems',
#   'liver problems',
#   'underweight',
#   'overweight',
#   'high level of potassium',
#   'a blood test',
#   'currently',
#   'medicines',
#   'potassium in your blood',
#   'any other medicines',
#   'warfarin',
#   'thinning the blood aspirin',
#   'acetylsalicylic acid',
#   'asa',
#   'clopidogrel',
#   'blood clots',
#   '3',
#   'anticoagulant medicine',
#   'dextran injection',
#   'a blood replacer ibuprofen',
#   'diclofenac',
#   'ketorolac',
#   'non - steroidal anti - inflammatory agents',
#   'pain',
#   'swelling in arthritis',
#   'prednisolone',
#   'dexamethasone',
#   'asthma',
#   'rheumatoid arthritis',
#   'other conditions medicines',
#   'potassium level',
#   'potassium salts',
#   'water pills',
#   'some medicines',
#   'heart problems',
#   'operations and anesthetics',
#   'a spinal puncture',
#   'epidural or spinal anaesthetic',
#   'spine',
#   'spinal surgery',
#   'pregnancy',
#   'pregnant',
#   'a mechanical heart valve',
#   'developing blood clots',
#   'machines thorinane',
#   'sodium this medicine',
#   '1 mmol sodium'],
#  ['the bleeding',
#   'swelling of the lips , mouth , throat or eyes )',
#   'redness',
#   'warmth',
#   'legs',
#   'symptoms',
#   'deep vein thrombosis',
#   'breathlessness',
#   'chest pain',
#   'fainting',
#   'coughing up blood',
#   'a pulmonary embolism',
#   'a painful rash',
#   'dark red spots under the skin',
#   'a blood test',
#   'your platelet count',
#   'side effects',
#   'affect',
#   '1',
#   '10',
#   'increases in liver enzymes',
#   'bruise',
#   'a blood problem',
#   'low platelet counts',
#   'patches',
#   'skin',
#   'skin rash',
#   'hives',
#   'urticaria',
#   'itchy red skin',
#   'bruising',
#   'pain at the injection site',
#   'decreased red blood cell count',
#   'high platelet counts in the blood',
#   '100',
#   'sudden severe headache',
#   'bleeding in the brain',
#   'tenderness',
#   'swelling in your stomach',
#   'bleeding in your stomach',
#   'large red irregularly shaped skin lesions',
#   'blisters',
#   'skin irritation',
#   'local irritation',
#   'yellowing of your skin or eyes',
#   'your urine',
#   'darker in colour',
#   'a liver problem',
#   '1 , 000',
#   'a rash',
#   'swallowing or breathing problems',
#   'swelling of your lips , face , throat or tongue',
#   'increased potassium in your blood',
#   'kidney problems',
#   'diabetes',
#   'an increase',
#   'eosinophils',
#   'your blood',
#   'hair loss',
#   'osteoporosis',
#   'your bones',
#   'tingling',
#   'numbness',
#   'muscular weakness',
#   'part of your body',
#   'a spinal puncture',
#   'a spinal anaesthetic',
#   'lost of control over your bladder or bowel',
#   'bladder',
#   'hard mass',
#   'lump at the injection site',
#   'appendix',
#   'this medicine'],
#  [],
#  ['chlorobutyl rubber stopper',
#   'a blue polypropylene plunger rod',
#   '10 pre - filled syringes'],
#  [],
#  ['amide - type local anaesthetics',
#   'severe liver problems',
#   'face',
#   'accidental contact with ears , eyes , nose and mouth',
#   'eyes',
#   'cold water or saline solution',
#   'numbness',
#   'blinking',
#   'sensation',
#   'a foreign body in the eye',
#   'the numbness',
#   'mucous membranes',
#   'mouth , nose and throat',
#   'slightly numb',
#   'pain in these areas',
#   'extra care',
#   'vagina',
#   'anus',
#   'slight numbness',
#   'ear',
#   '18',
#   'other medicines',
#   'any other medicines',
#   'the following medicines',
#   'local anaesthetics heart medicines',
#   'anti - arrhythmic medicines',
#   'medicines',
#   'high blood pressure',
#   'your heart rhythm',
#   'beta blockers )',
#   'your stomach acid ( cimetidine )',
#   'a disorder',
#   'oxygen in the blood ( methaemoglobinaemia )',
#   'benzocaine',
#   'a local anaesthetic',
#   'pain',
#   'itching',
#   'chloroquine',
#   'pamaquine',
#   'primaquine',
#   'quinine',
#   'malaria metoclopramide',
#   'feelings of sickness',
#   'nausea',
#   'vomiting',
#   'migraine glyceryl trinitrate',
#   'gtn',
#   'nitroglycerin',
#   'isosorbide mononitrate',
#   'erythrityl tetranitrate',
#   'pentaerythritol tetranitrate',
#   'other nitrate',
#   'nitrite medicines',
#   'angina',
#   'chest pain',
#   'heart',
#   'sodium nitroprusside',
#   'isosorbide dinitrate',
#   'heart failure',
#   'nitrofurantoin an antibiotic',
#   'urinary and kidney infections sulphonamides',
#   'sulpha medicines',
#   'sulfamethoxazole an antibiotic',
#   'urinary infections',
#   'sulfasalazine',
#   "crohn ' s disease",
#   'ulcerative colitis',
#   'rheumatoid arthritis',
#   'dapsone',
#   'skin conditions',
#   'leprosy',
#   'dermatitis',
#   'malaria',
#   'pneumonia',
#   'phenobarbital',
#   'phenytoin',
#   'epilepsy para - aminosalicylic acid ( pas )',
#   'tuberculosis',
#   'certain dyes ( aniline dyes',
#   'chemical pesticides',
#   'any barrier contraceptives',
#   'polyurethane - based material',
#   'pregnancy',
#   'your contraceptive',
#   'contraceptive',
#   'condoms',
#   'unable to develop or maintain an erection',
#   'reduced feeling in and around the penis',
#   'any medicine',
#   'pregnant',
#   'fertility senstend',
#   'penis'],
#  ['the valve',
#   'foreskin',
#   'valve',
#   '5',
#   'any excess spray',
#   'overdose',
#   'symptoms',
#   'light - headed',
#   'dizzy tingling of the skin',
#   'numbness',
#   'the tongue abnormal taste blurred vision',
#   'ringing',
#   'a disorder',
#   'oxygen',
#   'methaemoglobinaemia',
#   'certain medicines',
#   'skin',
#   'bluish',
#   'a lack of oxygen',
#   'low blood pressure',
#   'slowed breathing',
#   'stopped breathing',
#   'altered heart beat',
#   'heart'],
#  ['senstend',
#   'the penis pain',
#   'vagina',
#   'feeling in and around the vagina',
#   'vaginal thrush ( candida ) infection discomfort in the anus',
#   'rectum loss of feeling',
#   'the mouth difficulty',
#   'pain passing urine pain',
#   'the vagina discomfort',
#   'itching in the vulva and vagina',
#   'appendix v .'],
#  ['senstend'],
#  ['12', 'an aluminium spray container', 'metering valve'],
#  ['opdivo',
#   'complete resection in adults ( treatment',
#   'adults advanced renal cell carcinoma',
#   'previous therapies',
#   'a monoclonal antibody',
#   'nivolumab attaches',
#   'white blood cell',
#   'immune system',
#   'nivolumab blocks',
#   'the melanoma , lung , kidney , lymphoid , head and neck or bladder cancer cells',
#   'other anti - cancer medicines',
#   'these other medicines',
#   'these medicines'],
#  ['lung',
#   'inflammation of the intestines',
#   'colitis',
#   'stomach pain',
#   'mucus or blood in stool',
#   'inflammation of the liver ( hepatitis )',
#   'signs and symptoms',
#   'hepatitis',
#   'abnormal liver function tests',
#   'liver',
#   'eye',
#   'skin yellowing ( jaundice',
#   'pain on the right side',
#   'stomach area',
#   'tiredness',
#   'problems with your kidneys',
#   'abnormal kidney function tests',
#   'decreased volume of urine',
#   'your hormone producing glands',
#   'pituitary',
#   'thyroid',
#   'parathyroid',
#   'adrenal glands',
#   'glands',
#   'fatigue',
#   'extreme tiredness',
#   'weight change',
#   'headache',
#   'decreased blood levels of calcium',
#   'visual disturbances',
#   'diabetes ( symptoms',
#   'excessive thirst',
#   'passing of a greatly increased amount of urine',
#   'increase in appetite',
#   'a loss of weight',
#   'feeling tired',
#   'drowsy',
#   'weak , depressed',
#   'irritable',
#   'generally unwell',
#   'diabetic ketoacidosis',
#   'acid in the blood',
#   'diabetes',
#   'inflammation of the skin',
#   'severe skin reaction',
#   'toxic epidermal necrolysis',
#   'stevens - johnson syndrome',
#   'rash',
#   'itching',
#   'peeling of the skin',
#   'inflammation of the muscles',
#   'myocarditis',
#   'inflammation of the heart muscle',
#   'myositis',
#   'inflammation of the muscles )',
#   'rhabdomyolysis',
#   'stiffness in muscles and joints',
#   'muscle spasm',
#   'muscle pain',
#   'stiffness',
#   'weakness',
#   'chest pain',
#   'severe fatigue',
#   'solid organ transplant rejection',
#   'graft - versus - host disease',
#   'haemophagocytic lymphohistiocytosis',
#   'a rare disease',
#   'otherwise normal infection fighting cells',
#   'histiocytes',
#   'lymphocytes',
#   'enlarged liver and / or spleen',
#   'skin rash',
#   'lymph node enlargement',
#   'breathing problems',
#   'easy bruising',
#   'kidney abnormalities',
#   'heart problems',
#   'these signs or symptoms',
#   'your symptoms',
#   'other medicines',
#   'complications',
#   'your treatment',
#   'treatment',
#   'blood tests',
#   'an autoimmune disease',
#   'a condition',
#   'melanoma of the eye',
#   'ipilimumab',
#   'melanoma',
#   'serious side effects',
#   'your cancer',
#   'brain',
#   'medicines',
#   'stem cell transplant',
#   'donor stem cells',
#   'these complications',
#   'death',
# ...
#   'indigestion',
#   'asthenia',
#   '100',
#   'blood platelets',
#   'white blood cells',
#   'weight decrease',
#   'weight increase',
#   'suicide attempt',
#   'suicidal ideation',
#   'mental disorder',
#   'hallucination',
#   'anger',
#   'panic attack',
#   'emotional instability',
#   'mood swings',
#   'agitation',
#   'abnormal coordination / ataxia',
#   'impaired coordinated movements )',
#   'paraesthesia ( tingling )',
#   'disturbance in attention ( loss of concentration )',
#   'diplopia ( double vision )',
#   'vision blurred',
#   'elevated / abnormal values',
#   'a liver function test',
#   'hair loss',
#   'eczema',
#   'pruritus',
#   'muscle weakness',
#   'myalgia',
#   'muscle pain',
#   'injury',
#   '1 , 000',
#   'infection',
#   'all blood cell types',
#   'severe allergic reactions',
#   'anaphylactic reaction',
#   'important allergic reaction',
#   'decreased blood sodium concentration',
#   'suicide , personality disorders',
#   'behavioural problems',
#   'thinking abnormal ( slow thinking',
#   'unable to concentrate',
#   '57 delirium',
#   'encephalopathy',
#   'uncontrollable muscle spasms affecting the head , torso and limbs',
#   'difficulty in controlling movements',
#   'hyperkinesia ( hyperactivity )',
#   'pancreatitis',
#   'liver failure',
#   'hepatitis',
#   'sudden decrease in kidney function',
#   'kidney',
#   'skin rash',
#   'a dark ring',
#   'nose , eyes and genitals ( stevens johnson syndrome',
#   'rhabdomyolysis',
#   'breakdown of muscle tissue',
#   'associated blood creatine phosphokinase increase',
#   'limp',
#   'difficulty walking',
#   'appendix v .'],
#  ['crospovidon',
#   'povidone',
#   'silica colloidal anhydrous',
#   'magnesium stearate',
#   'polyvinyl alcoholpart',
#   'hydrolyzed',
#   'macrogol 4000',
#   'talc , titanium dioxide',
#   'colourants',
#   'indigo carmine',
#   'iron oxide yellow',
#   'iron oxide red',
#   'the pack',
#   '58',
#   'light blue',
#   '13 . 6',
#   '6 . 4',
#   '17 . 1',
#   '8 . 1',
#   '19 . 0',
#   '9 . 3',
#   '10 . 0',
#   '20',
#   '30',
#   '60',
#   '100',
#   '120',
#   '200',
#   'perforated unit dose blisters',
#   'film - coated tablets'],
#  ['difficulties in breathing',
#   'tightening',
#   'muscles',
#   'a sudden attack of breathlessness',
#   'wheezing',
#   'attack',
#   'a quick - acting reliever inhaler',
#   'salbutamol )'],
#  ['a blockage in your bladder',
#   'severe liver problems',
#   'immediate breathing difficulties',
#   'tightness of the chest',
#   'coughing',
#   'wheezing',
#   'breathlessness',
#   'immediately',
#   'your incruse ellipta inhaler',
#   'a serious condition',
#   'paradoxical bronchospasm',
#   'eye problems',
#   'treatment',
#   'eye pain',
#   'discomfort',
#   'temporary blurring of vision',
#   'visual halos',
#   'coloured images',
#   'red eyes',
#   'an acute attack of narrow - angle glaucoma',
#   '18',
#   'other medicines',
#   'any other medicines',
#   'long - acting medicines',
#   'breathing problems',
#   'tiotropium',
#   'these other medicines',
#   'pregnancy',
#   'pregnant',
#   'breast',
#   'machines',
#   'lactose',
#   'intolerance to some sugars'],
#  ['wheezing',
#   'a quick - acting reliever inhaler',
#   'salbutamol )',
#   'the inhaler',
#   'lungs',
#   'mouth',
#   'the ellipta inhaler',
#   'your symptoms',
#   'your copd symptoms',
#   'cough',
#   'your quick - acting inhaler',
#   'heart is beating faster than usual',
#   'visual disturbances',
#   'a dry mouth',
#   'wheezy',
#   'breathless',
#   'salbutamol',
#   'feel better'],
#  ['sinusitis',
#   'headache',
#   'constipation',
#   'uncommon side effects',
#   'irregular heart beat sore throat',
#   'dry mouth rash taste disturbance',
#   'rare side effects',
#   '1 , 000',
#   'eye pain',
#   'other side effects',
#   'frequency',
#   'decrease in vision',
#   'pain in your eyes',
#   'high pressure',
#   'glaucoma',
#   'blurred vision',
#   'the measured eye pressure difficulty',
#   'pain',
#   'passing urine',
#   'a bladder obstruction',
#   'urinary retention dizziness',
#   'appendix'],
#  ['incruse ellipta', 'medicines'],
#  ['a light green mouthpiece cover',
#   'a dose counter',
#   'a foil laminate tray',
#   'a peelable foil lid',
#   'a desiccant packet',
#   'the packaging',
#   'a white powder',
#   'each inhaler',
#   '7',
#   '30',
#   'multipacks',
#   '90'],
#  ['eosinophilic asthma',
#   'asthma nucala',
#   'high dose inhalers',
#   'your asthma',
#   'these medicines',
#   'oral corticosteroids',
#   'interleukin - 5',
#   'this protein',
#   'the bone marrow'],
#  ['their asthma',
#   'nucala treatment',
#   'body',
#   '4',
#   'a similar reaction',
#   'parasitic infections nucala',
#   'your resistance to infections',
#   'parasites',
#   'a parasitic infection',
#   'infections',
#   '12',
#   'other medicines',
#   'any other medicines',
#   'your preventer medicines',
#   'these medicines',
#   'corticosteroids',
#   'pregnancy',
#   'pregnant',
#   'breast',
#   'machines',
#   'sodium this medicine',
#   '1 mmol sodium',
#   '100'],
#  ['nucala', 'injections', 'this medicine'],
#  ['sometimes symptoms',
#   'symptoms',
#   'chest tightness',
#   'cough',
#   'difficulty breathing fainting',
#   'dizziness',
#   'feeling lightheaded',
#   'a similar reaction',
#   'headache',
#   'chest infection',
#   'fever',
#   'high temperature )',
#   'urinary tract infection',
#   'blood in urine',
#   'painful',
#   'frequent urination',
#   'pain in lower back )',
#   'upper abdominal pain',
#   'stomach pain',
#   'discomfort',
#   'area of the stomach',
#   'eczema ( itchy red patches',
#   'skin',
#   'site reaction',
#   'pain',
#   'redness',
#   'itching',
#   'burning sensation of the skin',
#   '60',
#   'back pain pharyngitis ( sore throat',
#   'nasal congestion ( stuffy nose',
#   'rare side effects',
#   '1 , 000',
#   'severe allergic reactions',
#   'anaphylaxis',
#   'these symptoms',
#   'appendix v .'],
#  ['the nucala pre - filled pen'],
#  ['the pack nucala'],
#  ['myeloma cells',
#   'lenalidomide',
#   'dexamethasone',
#   'a cancer of the blood',
#   'a plasma cell',
#   'a blood cell',
#   'fight infections',
#   'cancerous plasma cells',
#   'bones',
#   'protein',
#   'kidneys',
#   'treatment',
#   'killing myeloma cells',
#   'the symptoms',
#   'the disease'],
#  ['nerve problems',
#   'tingling',
#   'numbness',
#   'swelling',
#   'a persistent rash',
#   'liver or kidney problems',
#   'kidney',
#   'treatment',
#   'blood tests',
#   'enough blood cells',
#   '18',
#   'other medicines',
#   'any other medicines',
#   'any medicines',
#   'vitamins',
#   'herbal remedies',
#   'the following medicines',
#   'carbamazepine',
#   'phenytoin',
#   'rifampicin',
#   "st . john ' s wort",
#   'hypericum perforatum',
#   'these medicines',
#   'pregnancy',
#   'breast - feeding ninlaro',
#   'breast - feeding',
#   'pregnant',
#   'effective contraception',
#   '90 days',
#   'hormonal contraceptives',
#   'a barrier method of contraception',
#   'lenalidomide',
#   'pregnancy prevention programme',
#   'dexamethasone',
#   'breast - feeding driving',
#   'machines ninlaro',
#   'tired',
#   'dizzy',
#   'these side effects'],
#  ['4 - week',
#   'same day of the week',
#   '40',
#   'same day',
#   'these other medicines',
#   'liver or kidney problems',
#   'ninlaro capsules',
#   'side effects',
#   '2 . 3',
#   'the other medicines',
#   'skin',
#   'the capsule breaks',
#   'clean up the powder',
#   'the treatment',
#   'treatment',
#   '72',
#   'vomit',
#   'an extra dose',
#   'dexamethasone take medicine',
#   '28',
#   '1',
#   'day 1',
#   '7',
#   '8',
#   '9',
#   '14',
#   '15',
#   '16',
#   '21',
#   '22',
#   '23',
#   'ninlaro lenalidomide'],
#  ['ninlaro',
#   'body',
#   "sweet ' s syndrome",
#   'skin peeling',
#   'mouth sores',
#   'stevens - johnson syndrome',
#   'muscle weakness',
#   'loss of feelings of the toes and feet',
#   'loss of leg movement',
#   'leg',
#   'transverse myelitis )',
#   'changes in vision',
#   'changes in mental status',
#   'seizures',
#   'posterior reversible encephalopathy syndrome',
#   'rapid death of cancer cells',
#   'dizziness',
#   'decreased urination',
#   'confusion',
#   'shortness of breath',
#   'heart rhythm disturbances',
#   'tumour lysis syndrome',
#   'rare blood condition',
#   'blood clots',
#   'fatigue',
#   'fever',
#   'bruising',
#   'thrombotic thrombocytopenic purpura',
#   'very common side effects',
#   'constipation',
#   'back pain',
#   'cold - like symptoms',
#   'upper respiratory tract infection',
#   'respiratory tract',
#   'feeling tired',
#   'weak ( fatigue )',
#   'lowered white blood cells',
#   'neutrophils',
#   'neutropenia',
#   'infection',
#   'feeling like eating',
#   'decreased appetite',
#   'irregular heart rate ( arrhythmia ) vision conditions',
#   'blurred vision',
#   'dry eye',
#   'pink eye ( conjunctivitis',
#   'common side effects',
#   'reactivation',
#   'the chicken pox virus ( shingles',
#   'a skin rash',
#   'pain ( herpes zoster',
#   'lowered blood pressure ( hypotension )',
#   'persistent coughing',
#   'wheezing ( heart failure )',
#   'yellow discoloration of eyes and skin ( jaundice',
#   'liver impairment',
#   'low levels of potassium in the blood ( hypokalaemia',
#   'appendix'],
#  ['ninlaro', '30 .'],
#  ['what ninlaro',
#   '3 . 3',
#   'ixazomib citrate',
#   '5 . 7',
#   'yellow iron oxide',
#   'the pack ninlaro',
#   'the cap',
#   'body',
#   'black ink',
#   'each pack',
#   '3 hard capsules',
#   'a blister'],
#  [],
#  ['treatment',
#   'your palforzia',
#   'peanut allergy',
#   'an allergic reaction',
#   'allergic reactions',
#   'these reactions',
#   'a palforzia dose',
#   'medical treatment',
#   'the following symptoms',
#   'trouble breathing',
#   'throat tightness',
#   'feeling of fulness',
#   'trouble swallowing',
#   'change in voice',
#   'dizziness',
#   'fainting',
#   'feeling of impending doom',
#   'severe stomach cramps',
#   'pain',
#   'vomiting',
#   'diarrhoea',
#   'severe flushing',
#   'itching of the skin',
#   'any other breathing condition',
#   'heartburn',
#   'difficult swallowing',
#   'pain with swallowing',
#   'stomach pain',
#   'chest pain',
#   'certain conditions',
#   'an open sore',
#   'other damage',
#   'lining of the mouth',
#   'mouth',
#   'stomach',
#   'very tired',
#   'missing sleep',
#   'certain pain medications',
#   'aspirin',
#   'ibuprofen',
#   'adrenaline',
#   'a severe allergic reaction',
#   'the adrenaline',
#   'the adrenaline package leaflet',
#   'desensitisation',
#   'gradually increasing small amounts of peanut',
#   'all up - dosing levels of palforzia',
#   '3 months',
#   'maintenance therapy',
#   'the desensitisation',
#   'palforzia treatment',
#   '4',
#   '17',
#   'other medicines',
#   'any other medicines',
#   'alcohol palforzia',
#   '2',
#   'pregnancy',
#   'pregnant',
#   'machines palforzia',
#   'exercise caution',
#   'all symptoms',
#   'such allergic reactions'],
#  ['initial dose escalation',
#   'these treatment phases',
#   'the initial dose escalation and up - dosing phases',
#   'desensitisation',
#   'day',
#   'feeling unwell',
#   'your asthma',
#   '4 to 5 hours',
#   '5',
#   'first day',
#   '0 . 5',
#   '1',
#   '1 . 5',
#   '6',
#   '11',
#   '300',
#   'the up - dosing levels',
#   'daily dose dose level presentation of dose',
#   '2',
#   '12',
#   '10',
#   'blue',
#   '20',
#   '4',
#   '40',
#   '80',
#   '120',
#   '7',
#   '100',
#   '160',
#   '8',
#   '200',
#   '9',
#   '240',
#   '68',
#   'all 11 up - dosing levels',
#   'maintenance treatment',
#   '22',
#   'maintenance dosing',
#   'maintenance therapy',
#   'empty the powder from palforzia capsules',
#   'sachets',
#   'a capsule',
#   'soft food',
#   'empty the powder',
#   'finger',
#   'thumb',
#   'tap the ends of each half capsule',
#   'all the powder',
#   'a sachet carefully cut',
#   'tear',
#   'tip',
#   'tap the sachet',
#   'palforzia oral powder',
#   'a small amount of soft food',
#   'palforzia powder',
#   'breathing problems',
#   'asthma',
#   'an allergic reaction',
#   'hands',
#   'handling palforzia capsules',
#   'any extra doses',
#   'stomach',
#   'any symptoms',
#   'feeling hot',
#   'sweating',
#   'heart is beating fast',
#   'your heart rate',
#   'pulse',
#   'severe reactions',
#   'difficulty swallowing',
#   'difficulty breathing',
#   'changes in your voice',
#   'fullness in the throat',
#   'the reaction',
#   'adrenaline self - injector',
#   'immediately',
#   'a double dose',
#   'your treatment'],
#  ['the reaction',
#   'feeling of fulness',
#   'itching of the skin palforzia',
#   'eosinophilic oesophagitis',
#   'mouth',
#   '1',
#   '1 , 000',
#   'food stuck in throat',
#   'burning in chest , mouth',
#   'regurgitation',
#   'these symptoms',
#   'other side effects',
#   'affect',
#   '10',
#   'stomach discomfort',
#   'ache',
#   'feeling sick',
#   'mild or moderate )',
#   'cough',
#   'sneezing',
#   'throat irritation',
#   'stomach pain',
#   'tingling of mouth',
#   'hives',
#   'itchy skin',
#   '100',
#   'difficulty breathing',
#   'wheezing allergic reactions',
#   'affect different parts of the body',
#   'face swelling',
#   'rash',
#   'wheezing',
#   'runny nose',
#   'appendix v .'],
#  ['palforzia'],
#  ['magnesium stearate palforzia',
#   'oral powder in sachet microcrystalline cellulose',
#   'initial dose escalation ( see section',
#   '13',
#   'single - dose blisters',
#   '1 . 5',
#   '6',
#   '72',
#   'sachet strength pack contents',
#   '48',
#   '16',
#   '96',
#   '4',
#   '32',
#   '64',
#   '9',
#   '7',
#   '8',
#   '11',
#   '15'],
#  [],
#  ['zerene sleep apnoea syndrome',
#   'undesirable effects',
#   'any medicine',
#   'any medicines',
#   'physical dependence',
#   'treatment',
#   'withdrawal symptoms',
#   'headaches',
#   'muscle pain',
#   'extreme anxiety',
#   'tension',
#   'restlessness',
#   'confusion',
#   'irritability',
#   'a second dose of zerene',
#   'your sleeplessness',
#   'zerene treatment',
#   'temporary memory loss',
#   'amnesia',
#   'lack of coordination',
#   'sleep medicines',
#   '4',
#   'somnambulism ( sleepwalking )',
#   'awake',
#   'memory of the event',
#   'agitation',
#   'aggressiveness',
#   'abnormal thinking',
#   'delusion',
#   'rages',
#   'nightmares',
#   'depersonalisation',
#   'hallucinations',
#   'psychoses',
#   'inappropriate behaviour',
#   'extroversion',
#   'behavioural effects',
#   'these reactions',
#   'substance - induced',
#   'an underlying psychiatric or physical disorder',
#   'severe allergic reactions',
#   'an allergic reaction',
#   'a rash',
#   'itching',
#   'difficulty breathing',
#   'swelling of the face , lips , throat or tongue',
#   'nausea',
#   'vomiting',
#   'other medicines',
#   'medicines',
#   'drowsiness',
#   'brain',
#   'drowsy',
#   'next day',
#   'these medicines',
#   'substances',
#   'mental conditions',
#   'antipsychotics',
#   'hypnotics',
#   'anxiolytics',
#   'sedatives',
#   'antidepressants',
#   'strong pain relief',
#   'pain',
#   'narcotic analgesics',
#   'seizures',
#   'convulsions',
#   'antiepileptic medicines',
#   'loss of feeling',
#   'insensibility',
#   'anaesthetics',
#   'allergies',
#   'sedative antihistamines',
#   'cimetidine',
#   'a stomach medicine',
#   'erythromycin',
#   'an antibiotic',
#   'immediately',
#   'pregnancy',
#   'pregnant',
#   'breast - feeding',
#   'machines zerene',
#   'loss of concentration or memory',
#   'muscle weakness',
#   '7',
#   'your medication',
#   'intolerance to some sugars',
#   'this medicinal product'],
#  ['cloudy',
#   'an overdose',
#   'increasingly drowsy',
#   'a coma',
#   'treatment',
#   'your original sleeplessness',
#   'symptoms',
#   'mood changes',
#   'anxiety',
#   'restlessness',
#   'these symptoms'],
#  ['drowsiness',
#   'memory difficulties',
#   'sensations like tingling',
#   'extremities',
#   'paraesthesia',
#   'painful menstruation',
#   'uncommon side effects',
#   'dizziness',
#   'weakness',
#   'reduced coordination of movements',
#   'unsteadiness',
#   'falls ( ataxia )',
#   'decreased concentration',
#   'apathy',
#   'restlessness',
#   'depression',
#   'agitation',
#   'irritability',
#   'confusion',
#   'abnormal thinking and behaviour ( extroversion',
#   'decreased inhibition',
#   'aggressiveness',
#   'rages',
#   'delusion',
#   'depersonalisation',
#   'psychosis',
#   'nightmares',
#   'hallucinations',
#   'double vision',
#   'other sight problems',
#   'increased sensitivity to noise ( hyperacusis )',
#   'smell disorder ( parosmia )',
#   'speech disorders',
#   'slurred speech',
#   'numbness',
#   'e . g . in the extremities',
#   'hypoaesthesia',
#   'nausea',
#   'decreased appetite',
#   'increased sensitivity to light ( sunlight',
#   'uv light',
#   'feeling vaguely ill',
#   'malaise',
#   'allergic reactions',
#   'difficulty in breathing',
#   'immediate medical care',
#   'an allergic reaction',
#   'a rash',
#   'itching',
#   'swelling of the face , lips , throat or tongue',
#   'increases in transaminases',
#   'liver enzymes',
#   'liver problems',
#   'any side effects'],
#  ['black iron oxide ( e',
#   'shellac , lecithin',
#   'simethicone',
#   'the pack zerene',
#   'an intensely dark blue powder',
#   'a light brown cap',
#   'blisters',
#   '10',
#   '14']]

# %%
# calculate metrics

FAITHFULNESS = []
MISSING_FACTS = []
HALLUCINATION = []

for section_idx in range(len(test_outputs)):
        
    # get generated text at this index
    generated_section = test_outputs[sample_ind]
    
    # get input entities at this index
    input_entities = entities_inputs[sample_ind]
    
    entities_included = ENTITIES_INCLUDED[sample_ind]
    
    entities_not_included = ENTITIES_NOT_INCLUDED[sample_ind]
    
    entities_hallucinated = HALLUCINATED_ENTITIES[sample_ind]
    
    FAITHFULNESS.append(len(entities_included) / len(input_entities))
    MISSING_FACTS.append(len(entities_not_included) / len(input_entities))
    HALLUCINATION.append(len(entities_hallucinated) / len(input_entities))

# %%
print("FAITHFULNESS:", np.mean(FAITHFULNESS))
print("MISSING_FACTS:", np.mean(MISSING_FACTS))
print("HALLUCINATION:", np.mean(HALLUCINATION))
# Out:
# FAITHFULNESS: 0.6399999999999999
# MISSING_FACTS: 0.3599999999999999
# HALLUCINATION: 0.0
